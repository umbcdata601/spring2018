# %%
from traitlets.config.manager import BaseJSONConfigManager
path = '/Users/jmk/anaconda2/envs/data601/etc/jupyter/nbconfig'
cm = BaseJSONConfigManager(config_dir=path)
cm.update('livereveal', {
              'theme': 'simple',  
              #'transition': 'zoom',
              'start_slideshow_at': 'selected',
})

# theme names: biege, blood, default, moon, night, serif, simple, sky, solarized
# Out:
# {'scroll': True, 'start_slideshow_at': 'selected', 'theme': 'simple'}

# %% [markdown]
# # About Data
#
# TL;DR  The measurements are not "the thing" being measured.  They are a simplified model of it.

# %% [markdown]
# * Data are measurements of a phenomenon
# * Formats are a representation of the data
# * Systems store formatted data
#
# These are very interconnected.

# %% [markdown]
# For example,
#
# * The solar system has planets
# * Each planet has 0+ moons
# * The moon-count for each planet is `[0, 0, 1, 2, 67, 62, 27, 14]` (Source:  https://www.windows2universe.org/our_solar_system/moons_table.html)
# * Those can be written as above (a python list) or a CSV file `0,0,1,2,67,27,14` or XML
#
# ```
# ...
# <mooncount>
#    <planet name="Mercury" moons="0" />
#    ...
# </mooncount>
# ...
# ```
#
# ... or any number of arbitrary formats.
# * Those can be stored inside of filesystems, databases, etc.

# %% [markdown]
# * The process of writing data in a format like this is often called "serialization".
# * e.g. "I serialized the data to a JSON file in order to store it in the database"

# %% [markdown]
# ## Why bother?

# %% [markdown]
# ### To make data portable!

# %% [markdown]
# # Common Formats
# For this semester, you'll mostly _read_ from these formats using libraries that are built just for that purpose.  The goal is to get data into your program in a form that you can use.
#
# There's a deep, deep rabbit hole to follow if you're interested in the intricacies of any of these formats.

# %% [markdown]
# # CSV
# * It's a plain text representation of tabular data
# * You can think of it as a tab from a spreadsheet
# * It's like a "list of rows of cells"
#
# ## Basic rules
# * One row per line (usually)
# * Each value separated by a comma (`,`)
# * Quotes are allowed so that commas can appear inside of cells or newlines can appear inside of cells

# %% [markdown]
# # Example...
# ```
# RM,LSTAT,PTRATIO,MDEV
# 6.575,4.98,15.3,504000.0
# 6.421,9.14,17.8,453600.0
# 7.185,4.03,17.8,728700.0
# ...
# ```
# (source:  Boston Housing Prices Dataset copied here https://raw.githubusercontent.com/ggallo/boston-housing/master/housing.csv)
#
# ## Note that the first row is often labels for each column

# %% [markdown]
# # JSON
# * JavaScript Object Notation
# * It's a way to write out a data structure literal in JavaScript
# * As JavaScript has risen to ubiquity for modern web UIs, JSON has become a simple format for serializing data to transmit from servers to browsers
# * Turns out to be a simple and fairly universal way to represent and transmit most basic data structures between languages
# * The format is almost identical to what's used in python dictionaries and lists
# * Supports arbitrary nesting

# %% [markdown]
# # Example JSON
# ```
# [
#   {'RM': 6.575, 'LSTAT': 4.98, 'PTRATIO': 15.3, 'MDEV': 504000.0},
#   ...
# ]
# ```

# %% [markdown]
# # XML
# * "Tag"-based markup language
# * More structured than HTML (Common ancestor in SGML)
# * Can be parsed as a one-shot document object model (DOM)
# * Can also be parsed in a "streaming" fashion (via Simple API for XML (aka SAX))

# %% [markdown]
# # Example XML
# ```
# <?xml version="1.0" encoding="UTF-8"?>
# <note>
#   <to>Tove</to>
#   <from>Jani</from>
#   <heading>Reminder</heading>
#   <body>Don't forget me <em>this</em> weekend!</body>
# </note>
# ```
#
# ## Note the open _and_ close tags.  These allow XML to "mark up" other content.

# %% [markdown]
# #  Field Trip!
#
# Well, sort of:  https://en.m.wikipedia.org/wiki/Comparison_of_data_serialization_formats

# %% [markdown]
# # From disk to memory
# * To load data from one of these formats...
# * ... we first read them from disk
# * ... then "parse" them to convert them from a complex string to a data structure!
#
# ## Normally there's a library for a format.  Use it.  (e.g. `import csv`)

# %%
# Parsing a CSV file in python...
import csv
import requests
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    
response = requests.get('https://raw.githubusercontent.com/ggallo/boston-housing/master/housing.csv')
print(response)
print(response.content)
# Out:
# <Response [200]>
# b'RM,LSTAT,PTRATIO,MDEV\n6.575,4.98,15.3,504000.0\n6.421,9.14,17.8,453600.0\n7.185,4.03,17.8,728700.0\n6.998,2.94,18.7,701400.0\n7.147,5.33,18.7,760200.0\n6.43,5.21,18.7,602700.0\n6.012,12.43,15.2,480900.0\n6.172,19.15,15.2,569100.0\n5.631,29.93,15.2,346500.0\n6.004,17.1,15.2,396900.0\n6.377,20.45,15.2,315000.0\n6.009,13.27,15.2,396900.0\n5.889,15.71,15.2,455700.0\n5.949,8.26,21.0,428400.0\n6.096,10.26,21.0,382200.0\n5.834,8.47,21.0,417900.0\n5.935,6.58,21.0,485100.0\n5.99,14.67,21.0,367500.0\n5.456,11.69,21.0,424200.0\n5.727,11.28,21.0,382200.0\n5.57,21.02,21.0,285600.0\n5.965,13.83,21.0,411600.0\n6.142,18.72,21.0,319200.0\n5.813,19.88,21.0,304500.0\n5.924,16.3,21.0,327600.0\n5.599,16.51,21.0,291900.0\n5.813,14.81,21.0,348600.0\n6.047,17.28,21.0,310800.0\n6.495,12.8,21.0,386400.0\n6.674,11.98,21.0,441000.0\n5.713,22.6,21.0,266700.0\n6.072,13.04,21.0,304500.0\n5.95,27.71,21.0,277200.0\n5.701,18.35,21.0,275100.0\n6.096,20.34,21.0,283500.0\n5.933,9.68,19.2,396900.0\n5.841,11.41,19.2,420000.0\n5.85,8.77,19.2,441000.0\n5.966,10.13,19.2,518700.0\n6.595,4.32,18.3,646800.0\n7.024,1.98,18.3,732900.0\n6.77,4.84,17.9,558600.0\n6.169,5.81,17.9,531300.0\n6.211,7.44,17.9,518700.0\n6.069,9.55,17.9,445200.0\n5.682,10.21,17.9,405300.0\n5.786,14.15,17.9,420000.0\n6.03,18.8,17.9,348600.0\n5.399,30.81,17.9,302400.0\n5.602,16.2,17.9,407400.0\n5.963,13.45,16.8,413700.0\n6.115,9.43,16.8,430500.0\n6.511,5.28,16.8,525000.0\n5.998,8.43,16.8,491400.0\n5.888,14.8,21.1,396900.0\n7.249,4.81,17.9,743400.0\n6.383,5.77,17.3,518700.0\n6.816,3.95,15.1,663600.0\n6.145,6.86,19.7,489300.0\n5.927,9.22,19.7,411600.0\n5.741,13.15,19.7,392700.0\n5.966,14.44,19.7,336000.0\n6.456,6.73,19.7,466200.0\n6.762,9.5,19.7,525000.0\n7.104,8.05,18.6,693000.0\n6.29,4.67,16.1,493500.0\n5.787,10.24,16.1,407400.0\n5.878,8.1,18.9,462000.0\n5.594,13.09,18.9,365400.0\n5.885,8.79,18.9,438900.0\n6.417,6.72,19.2,508200.0\n5.961,9.88,19.2,455700.0\n6.065,5.52,19.2,478800.0\n6.245,7.54,19.2,491400.0\n6.273,6.78,18.7,506100.0\n6.286,8.94,18.7,449400.0\n6.279,11.97,18.7,420000.0\n6.14,10.27,18.7,436800.0\n6.232,12.34,18.7,445200.0\n5.874,9.1,18.7,426300.0\n6.727,5.29,19.0,588000.0\n6.619,7.22,19.0,501900.0\n6.302,6.72,19.0,520800.0\n6.167,7.51,19.0,480900.0\n6.389,9.62,18.5,501900.0\n6.63,6.53,18.5,558600.0\n6.015,12.86,18.5,472500.0\n6.121,8.44,18.5,466200.0\n7.007,5.5,17.8,495600.0\n7.079,5.7,17.8,602700.0\n6.417,8.81,17.8,474600.0\n6.405,8.2,17.8,462000.0\n6.442,8.16,18.2,480900.0\n6.211,6.21,18.2,525000.0\n6.249,10.59,18.2,432600.0\n6.625,6.65,18.0,596400.0\n6.163,11.34,18.0,449400.0\n8.069,4.21,18.0,812700.0\n7.82,3.57,18.0,919800.0\n7.416,6.19,18.0,697200.0\n6.727,9.42,20.9,577500.0\n6.781,7.67,20.9,556500.0\n6.405,10.63,20.9,390600.0\n6.137,13.44,20.9,405300.0\n6.167,12.33,20.9,422100.0\n5.851,16.47,20.9,409500.0\n5.836,18.66,20.9,409500.0\n6.127,14.09,20.9,428400.0\n6.474,12.27,20.9,415800.0\n6.229,15.55,20.9,407400.0\n6.195,13.0,20.9,455700.0\n6.715,10.16,17.8,478800.0\n5.913,16.21,17.8,394800.0\n6.092,17.09,17.8,392700.0\n6.254,10.45,17.8,388500.0\n5.928,15.76,17.8,384300.0\n6.176,12.04,17.8,445200.0\n6.021,10.3,17.8,403200.0\n5.872,15.37,17.8,428400.0\n5.731,13.61,17.8,405300.0\n5.87,14.37,19.1,462000.0\n6.004,14.27,19.1,426300.0\n5.961,17.93,19.1,430500.0\n5.856,25.41,19.1,363300.0\n5.879,17.58,19.1,394800.0\n5.986,14.81,19.1,449400.0\n5.613,27.26,19.1,329700.0\n5.693,17.19,21.2,340200.0\n6.431,15.39,21.2,378000.0\n5.637,18.34,21.2,300300.0\n6.458,12.6,21.2,403200.0\n6.326,12.26,21.2,411600.0\n6.372,11.12,21.2,483000.0\n5.822,15.03,21.2,386400.0\n5.757,17.31,21.2,327600.0\n6.335,16.96,21.2,380100.0\n5.942,16.9,21.2,365400.0\n6.454,14.59,21.2,359100.0\n5.857,21.32,21.2,279300.0\n6.151,18.46,21.2,373800.0\n6.174,24.16,21.2,294000.0\n5.019,34.41,21.2,302400.0\n5.403,26.82,14.7,281400.0\n5.468,26.42,14.7,327600.0\n4.903,29.29,14.7,247800.0\n6.13,27.8,14.7,289800.0\n5.628,16.65,14.7,327600.0\n4.926,29.53,14.7,306600.0\n5.186,28.32,14.7,373800.0\n5.597,21.45,14.7,323400.0\n6.122,14.1,14 ...

# %%
fake_file = StringIO(response.text)
sheet = [line.replace('\n', '').split(',') for line in fake_file]

fake_file = StringIO(response.text)
reader = csv.reader(fake_file)
csvsheet = [row for row in reader]
csvsheet
# Out:
# [['RM', 'LSTAT', 'PTRATIO', 'MDEV'],
#  ['6.575', '4.98', '15.3', '504000.0'],
#  ['6.421', '9.14', '17.8', '453600.0'],
#  ['7.185', '4.03', '17.8', '728700.0'],
#  ['6.998', '2.94', '18.7', '701400.0'],
#  ['7.147', '5.33', '18.7', '760200.0'],
#  ['6.43', '5.21', '18.7', '602700.0'],
#  ['6.012', '12.43', '15.2', '480900.0'],
#  ['6.172', '19.15', '15.2', '569100.0'],
#  ['5.631', '29.93', '15.2', '346500.0'],
#  ['6.004', '17.1', '15.2', '396900.0'],
#  ['6.377', '20.45', '15.2', '315000.0'],
#  ['6.009', '13.27', '15.2', '396900.0'],
#  ['5.889', '15.71', '15.2', '455700.0'],
#  ['5.949', '8.26', '21.0', '428400.0'],
#  ['6.096', '10.26', '21.0', '382200.0'],
#  ['5.834', '8.47', '21.0', '417900.0'],
#  ['5.935', '6.58', '21.0', '485100.0'],
#  ['5.99', '14.67', '21.0', '367500.0'],
#  ['5.456', '11.69', '21.0', '424200.0'],
#  ['5.727', '11.28', '21.0', '382200.0'],
#  ['5.57', '21.02', '21.0', '285600.0'],
#  ['5.965', '13.83', '21.0', '411600.0'],
#  ['6.142', '18.72', '21.0', '319200.0'],
#  ['5.813', '19.88', '21.0', '304500.0'],
#  ['5.924', '16.3', '21.0', '327600.0'],
#  ['5.599', '16.51', '21.0', '291900.0'],
#  ['5.813', '14.81', '21.0', '348600.0'],
#  ['6.047', '17.28', '21.0', '310800.0'],
#  ['6.495', '12.8', '21.0', '386400.0'],
#  ['6.674', '11.98', '21.0', '441000.0'],
#  ['5.713', '22.6', '21.0', '266700.0'],
#  ['6.072', '13.04', '21.0', '304500.0'],
#  ['5.95', '27.71', '21.0', '277200.0'],
#  ['5.701', '18.35', '21.0', '275100.0'],
#  ['6.096', '20.34', '21.0', '283500.0'],
#  ['5.933', '9.68', '19.2', '396900.0'],
#  ['5.841', '11.41', '19.2', '420000.0'],
#  ['5.85', '8.77', '19.2', '441000.0'],
#  ['5.966', '10.13', '19.2', '518700.0'],
#  ['6.595', '4.32', '18.3', '646800.0'],
#  ['7.024', '1.98', '18.3', '732900.0'],
#  ['6.77', '4.84', '17.9', '558600.0'],
#  ['6.169', '5.81', '17.9', '531300.0'],
#  ['6.211', '7.44', '17.9', '518700.0'],
#  ['6.069', '9.55', '17.9', '445200.0'],
#  ['5.682', '10.21', '17.9', '405300.0'],
#  ['5.786', '14.15', '17.9', '420000.0'],
#  ['6.03', '18.8', '17.9', '348600.0'],
#  ['5.399', '30.81', '17.9', '302400.0'],
#  ['5.602', '16.2', '17.9', '407400.0'],
#  ['5.963', '13.45', '16.8', '413700.0'],
#  ['6.115', '9.43', '16.8', '430500.0'],
#  ['6.511', '5.28', '16.8', '525000.0'],
#  ['5.998', '8.43', '16.8', '491400.0'],
#  ['5.888', '14.8', '21.1', '396900.0'],
#  ['7.249', '4.81', '17.9', '743400.0'],
#  ['6.383', '5.77', '17.3', '518700.0'],
#  ['6.816', '3.95', '15.1', '663600.0'],
#  ['6.145', '6.86', '19.7', '489300.0'],
#  ['5.927', '9.22', '19.7', '411600.0'],
#  ['5.741', '13.15', '19.7', '392700.0'],
#  ['5.966', '14.44', '19.7', '336000.0'],
#  ['6.456', '6.73', '19.7', '466200.0'],
#  ['6.762', '9.5', '19.7', '525000.0'],
#  ['7.104', '8.05', '18.6', '693000.0'],
#  ['6.29', '4.67', '16.1', '493500.0'],
#  ['5.787', '10.24', '16.1', '407400.0'],
#  ['5.878', '8.1', '18.9', '462000.0'],
#  ['5.594', '13.09', '18.9', '365400.0'],
#  ['5.885', '8.79', '18.9', '438900.0'],
#  ['6.417', '6.72', '19.2', '508200.0'],
#  ['5.961', '9.88', '19.2', '455700.0'],
#  ['6.065', '5.52', '19.2', '478800.0'],
#  ['6.245', '7.54', '19.2', '491400.0'],
#  ['6.273', '6.78', '18.7', '506100.0'],
#  ['6.286', '8.94', '18.7', '449400.0'],
#  ['6.279', '11.97', '18.7', '420000.0'],
#  ['6.14', '10.27', '18.7', '436800.0'],
#  ['6.232', '12.34', '18.7', '445200.0'],
#  ['5.874', '9.1', '18.7', '426300.0'],
#  ['6.727', '5.29', '19.0', '588000.0'],
#  ['6.619', '7.22', '19.0', '501900.0'],
#  ['6.302', '6.72', '19.0', '520800.0'],
#  ['6.167', '7.51', '19.0', '480900.0'],
#  ['6.389', '9.62', '18.5', '501900.0'],
#  ['6.63', '6.53', '18.5', '558600.0'],
#  ['6.015', '12.86', '18.5', '472500.0'],
#  ['6.121', '8.44', '18.5', '466200.0'],
#  ['7.007', '5.5', '17.8', '495600.0'],
#  ['7.079', '5.7', '17.8', '602700.0'],
#  ['6.417', '8.81', '17.8', '474600.0'],
#  ['6.405', '8.2', '17.8', '462000.0'],
#  ['6.442', '8.16', '18.2', '480900.0'],
#  ['6.211', '6.21', '18.2', '525000.0'],
#  ['6.249', '10.59', '18.2', '432600.0'],
#  ['6.625', '6.65', '18.0', '596400.0'],
#  ['6.163', '11.34', '18.0', '449400.0'],
#  ['8.069', '4.21', '18.0', '812700.0'],
#  ['7.82', '3.57', '18.0', '919800.0'],
#  ['7.416', '6.19', '18.0', '697200.0'],
#  ['6.727', '9.42', '20.9', '577500.0'],
#  ['6.781', '7.67', '20.9', '556500.0'],
#  ['6.405', '10.63', '20.9', '390600.0'],
#  ['6.137', '13.44', '20.9', '405300.0'],
#  ['6.167', '12.33', '20.9', '422100.0'],
#  ['5.851', '16.47', '20.9', '409500.0'],
#  ['5.836', '18.66', '20.9', '409500.0'],
#  ['6.127', '14.09', '20.9', '428400.0'],
#  ['6.474', '12.27', '20.9', '415800.0'],
#  ['6.229', '15.55', '20.9', '407400.0'],
#  ['6.195', '13.0', '20.9', '455700.0'],
#  ['6.715', '10.16', '17.8', '478800.0'],
#  ['5.913', '16.21', '17.8', '394800.0'],
#  ['6.092', '17.09', '17.8', '392700.0'],
#  ['6.254', '10.45', '17.8', '388500.0'],
#  ['5.928', '15.76', '17.8', '384300.0'],
#  ['6.176', '12.04', '17.8', '445200.0'],
#  ['6.021', '10.3', '17.8', '403200.0'],
#  ['5.872', '15.37', '17.8', '428400.0'],
#  ['5.731', '13.61', '17.8', '405300.0'],
#  ['5.87', '14.37', '19.1', '462000.0'],
#  ['6.004', '14.27', '19.1', '426300.0'],
#  ['5.961', '17.93', '19.1', '430500.0'],
#  ['5.856', '25.41', '19.1', '363300.0'],
#  ['5.879', '17.58', '19.1', '394800.0'],
#  ['5.986', '14.81', '19.1', '449400.0'],
#  ['5.613', '27.26', '19.1', '329700.0'],
#  ['5.693', '17.19', '21.2', '340200.0'],
#  ['6.431', '15.39', '21.2', '378000.0'],
#  ['5.637', '18.34', '21.2', '300300.0'],
#  ['6.458', '12.6', '21.2', '403200.0'],
#  ['6.326', '12.26', '21.2', '411600.0'],
#  ['6.372', '11.12', '21.2', '483000.0'],
#  ['5.822', '15.03', '21.2', '386400.0'],
#  ['5.757', '17.31', '21.2', '327600.0'],
#  ['6.335', '16.96', '21.2', '380100.0'],
#  ['5.942', '16.9', '21.2', '365400.0'],
#  ['6.454', '14.59', '21.2', '359100.0'],
#  ['5.857', '21.32', '21.2', '279300.0'],
#  ['6.151', '18.46', '21.2', '373800.0'],
#  ['6.174', '24.16', '21.2', '294000.0'],
#  ['5.019', '34.41', '21.2', '302400.0'],
#  ['5.403', '26.82', '14.7', '281400.0'],
#  ['5.468', '26.42', '14.7', '327600.0'],
#  ['4.903', '29.29', '14.7', '247800.0'],
#  ['6.13', '27.8', '14.7', '289800.0'],
#  ['5.628', '16.65', '14.7', '327600.0'],
#  ['4.926', '29.53', '14.7', '306600.0'],
#  ['5.186', '28.32', '14.7', '373800.0'],
#  ['5.597', '21.45', '14.7', '323400.0'],
#  ['6.122', '14.1', '14.7', '451500.0'],
#  ['5.404', '13.28', '14.7', '411600.0'],
#  ['5.012', '12.12', '14.7', '321300.0'],
#  ['5.709', '15.79', '14.7', '407400.0'],
#  ['6.129', '15.12', '14.7', '357000.0'],
#  ['6.152', '15.02', '14.7', '327600.0'],
#  ['5.272', '16.14', '14.7', '275100.0'],
#  ['6.943', '4.59', '14.7', '867300.0'],
#  ['6.066', '6.43', '14.7', '510300.0'],
#  ['6.51', '7.39', '14.7', '489300.0'],
#  ['6.25', '5.5', '14.7', '567000.0'],
#  ['5.854', '11.64', '14.7', '476700.0'],
#  ['6.101', '9.81', '14.7', '525000.0'],
#  ['5.877', '12.14', '14.7', '499800.0'],
#  ['6.319', '11.1', '14.7', '499800.0'],
#  ['6.402', '11.32', '14.7', '468300.0'],
#  ['5.875', '14.43', '14.7', '365400.0'],
#  ['5.88', '12.03', '14.7', '401100.0'],
#  ['5.572', '14.69', '16.6', '485100.0'],
#  ['6.416', '9.04', '16.6', '495600.0'],
#  ['5.859', '9.64', '16.6', '474600.0'],
#  ['6.546', '5.33', '16.6', '617400.0'],
#  ['6.02', '10.11', '16.6', '487200.0'],
#  ['6.315', '6.29', '16.6', '516600.0'],
#  ['6.86', '6.92', '16.6', '627900.0'],
#  ['6.98', '5.04', '17.8', '781200.0'],
#  ['7.765', '7.56', '17.8', '835800.0'],
#  ['6.144', '9.45', '17.8', '760200.0'],
#  ['7.155', '4.82', '17.8', '795900.0'],
#  ['6.563', '5.68', '17.8', '682500.0'],
#  ['5.604', '13.98', '17.8', '554400.0'],
#  ['6.153', '13.15', '17.8', '621600.0'],
#  ['6.782', '6.68', '15.2', '672000.0'],
#  ['6.556', '4.56', '15.2', '625800.0'],
#  ['7.185', '5.39', '15.2', '732900.0'],
#  ['6.951', '5.1', '15.2', '777000.0'],
#  ['6.739', '4.69', '15.2', '640500.0'],
#  ['7.178', '2.87', '15.2', '764400.0'],
#  ['6.8', '5.03', '15.6', '653100.0'],
#  ['6.604', '4.38', '15.6', '611100.0'],
#  ['7.287', '4.08', '12.6', '699300.0'],
#  ['7.107', '8.61', '12.6', '636300.0'],
#  ['7.274', '6.62', '12.6', '726600.0'],
#  ['6.975', '4.56', '17.0', '732900.0'],
#  ['7.135', '4.45', '17.0', '690900.0'],
#  ['6.162', '7.43', '14.7', '506100.0'],
#  ['7.61', '3.11', '14.7', '888300.0'],
#  ['7.853', '3.81', '14.7', '1018500.0'],
#  ['5.891', '10.87', '18.6', '474600.0'],
#  ['6.326', '10.97', '18.6', '512400.0'],
#  ['5.783', '18.06', '18.6', '472500.0'],
#  ['6.064', '14.66', '18.6', '512400.0'],
#  ['5.344', '23.09', '18.6', '420000.0'],
#  ['5.96', '17.27', '18.6', '455700.0'],
#  ['5.404', '23.98', '18.6', '405300.0'],
#  ['5.807', '16.03', '18.6', '470400.0'],
#  ['6.375', '9.38', '18.6', '590100.0'],
#  ['5.412', '29.55', '18.6', '497700.0'],
#  ['6.182', '9.47', '18.6', '525000.0'],
#  ['5.888', '13.51', '16.4', '489300.0'],
#  ['6.642', '9.69', '16.4', '602700.0'],
#  ['5.951', '17.92', '16.4', '451500.0'],
#  ['6.373', '10.5', '16.4', '483000.0'],
#  ['6.951', '9.71', '17.4', '560700.0'],
#  ['6.164', '21.46', '17.4', '455700.0'],
#  ['6.879', '9.93', '17.4', '577500.0'],
#  ['6.618', '7.6', '17.4', '632100.0'],
#  ['8.266', '4.14', '17.4', '940800.0'],
#  ['8.04', '3.13', '17.4', '789600.0'],
#  ['7.163', '6.36', '17.4', '663600.0'],
#  ['7.686', '3.92', '17.4', '980700.0'],
#  ['6.552', '3.76', '17.4', '661500.0'],
#  ['5.981', '11.65', '17.4', '510300.0'],
#  ['7.412', '5.25', '17.4', '665700.0'],
#  ['8.337', '2.47', '17.4', '875700.0'],
#  ['8.247', '3.95', '17.4', '1014300.0'],
#  ['6.726', '8.05', '17.4', '609000.0'],
#  ['6.086', '10.88', '17.4', '504000.0'],
#  ['6.631', '9.54', '17.4', '527100.0'],
#  ['7.358', '4.73', '17.4', '661500.0'],
#  ['6.481', '6.36', '16.6', '497700.0'],
#  ['6.606', '7.37', '16.6', '489300.0'],
#  ['6.897', '11.38', '16.6', '462000.0'],
#  ['6.095', '12.4', '16.6', '422100.0'],
#  ['6.358', '11.22', '16.6', '466200.0'],
#  ['6.393', '5.19', '16.6', '497700.0'],
#  ['5.593', '12.5', '19.1', '369600.0'],
#  ['5.605', '18.46', '19.1', '388500.0'],
#  ['6.108', '9.16', '19.1', '510300.0'],
#  ['6.226', '10.15', '19.1', '430500.0'],
#  ['6.433', '9.52', '19.1', '514500.0'],
#  ['6.718', '6.56', '19.1', '550200.0'],
#  ['6.487', '5.9', '19.1', '512400.0'],
#  ['6.438', '3.59', '19.1', '520800.0'],
#  ['6.957', '3.53', '19.1', '621600.0'],
#  ['8.259', '3.54', '19.1', '898800.0'],
#  ['6.108', '6.57', '16.4', '459900.0'],
#  ['5.876', '9.25', '16.4', '438900.0'],
#  ['7.454', '3.11', '15.9', '924000.0'],
#  ['7.333', '7.79', '13.0', '756000.0'],
#  ['6.842', '6.9', '13.0', '632100.0'],
#  ['7.203', '9.59', '13.0', '709800.0'],
#  ['7.52', '7.26', '13.0', '905100.0'],
#  ['8.398', '5.91', '13.0', '1024800.0'],
#  ['7.327', '11.25', '13.0', '651000.0'],
#  ['7.206', '8.1', '13.0', '766500.0'],
#  ['5.56', '10.45', '13.0', '478800.0'],
#  ['7.014', '14.79', '13.0', '644700.0'],
#  ['7.47', '3.16', '13.0', '913500.0'],
#  ['5.92', '13.65', '18.6', '434700.0'],
#  ['5.856', '13.0', '18.6', '443100.0'],
#  ['6.24', '6.59', '18.6', '529200.0'],
#  ['6.538', '7.73', '18.6', '512400.0'],
#  ['7.691', '6.58', '18.6', '739200.0'],
#  ['6.758', '3.53', '17.6', '680400.0'],
#  ['6.854', '2.98', '17.6', '672000.0'],
#  ['7.267', '6.05', '17.6', '697200.0'],
#  ['6.826', '4.16', '17.6', '695100.0'],
#  ['6.482', '7.19', '17.6', '611100.0'],
#  ['6.812', '4.85', '14.9', '737100.0'],
#  ['7.82', '3.76', '14.9', '953400.0'],
#  ['6.968', '4.59', '14.9', '743400.0'],
#  ['7.645', '3.01', '14.9', '966000.0'],
#  ['7.088', '7.85', '15.3', '676200.0'],
#  ['6.453', '8.23', '15.3', '462000.0'],
#  ['6.23', '12.93', '18.2', '422100.0'],
#  ['6.209', '7.14', '16.6', '487200.0'],
#  ['6.315', '7.6', '16.6', '468300.0'],
#  ['6.565', '9.51', '16.6', '520800.0'],
#  ['6.861', '3.33', '19.2', '598500.0'],
#  ['7.148', '3.56', '19.2', '783300.0'],
#  ['6.63', '4.7', '19.2', '585900.0'],
#  ['6.127', '8.58', '16.0', '501900.0'],
#  ['6.009', '10.4', '16.0', '455700.0'],
#  ['6.678', '6.27', '16.0', '600600.0'],
#  ['6.549', '7.39', '16.0', '569100.0'],
#  ['5.79', '15.84', '16.0', '426300.0'],
#  ['6.345', '4.97', '14.8', '472500.0'],
#  ['7.041', '4.74', '14.8', '609000.0'],
#  ['6.871', '6.07', '14.8', '520800.0'],
#  ['6.59', '9.5', '16.1', '462000.0'],
#  ['6.495', '8.67', '16.1', '554400.0'],
#  ['6.982', '4.86', '16.1', '695100.0'],
#  ['7.236', '6.93', '18.4', '758100.0'],
#  ['6.616', '8.93', '18.4', '596400.0'],
#  ['7.42', '6.47', '18.4', '701400.0'],
#  ['6.849', '7.53', '18.4', '592200.0'],
#  ['6.635', '4.54', '18.4', '478800.0'],
#  ['5.972', '9.97', '18.4', '426300.0'],
#  ['4.973', '12.64', '18.4', '338100.0'],
#  ['6.122', '5.98', '18.4', '464100.0'],
#  ['6.023', '11.72', '18.4', '407400.0'],
#  ['6.266', '7.9', '18.4', '453600.0'],
#  ['6.567', '9.28', '18.4', '499800.0'],
#  ['5.705', '11.5', '18.4', '340200.0'],
#  ['5.914', '18.33', '18.4', '373800.0'],
#  ['5.782', '15.94', '18.4', '415800.0'],
#  ['6.382', '10.36', '18.4', '485100.0'],
#  ['6.113', '12.73', '18.4', '441000.0'],
#  ['6.426', '7.2', '19.6', '499800.0'],
#  ['6.376', '6.87', '19.6', '485100.0'],
#  ['6.041', '7.7', '19.6', '428400.0'],
#  ['5.708', '11.74', '19.6', '388500.0'],
#  ['6.415', '6.12', '19.6', '525000.0'],
#  ['6.431', '5.08', '19.6', '516600.0'],
#  ['6.312', '6.15', '19.6', '483000.0'],
#  ['6.083', '12.79', '19.6', '466200.0'],
#  ['5.868', '9.97', '16.9', '405300.0'],
#  ['6.333', '7.34', '16.9', '474600.0'],
#  ['6.144', '9.09', '16.9', '415800.0'],
#  ['5.706', '12.43', '16.9', '359100.0'],
#  ['6.031', '7.83', '16.9', '407400.0'],
#  ['6.316', '5.68', '20.2', '466200.0'],
#  ['6.31', '6.75', '20.2', '434700.0'],
#  ['6.037', '8.01', '20.2', '443100.0'],
#  ['5.869', '9.8', '20.2', '409500.0'],
#  ['5.895', '10.56', '20.2', '388500.0'],
#  ['6.059', '8.51', '20.2', '432600.0'],
#  ['5.985', '9.74', '20.2', '399000.0'],
#  ['5.968', '9.29', '20.2', '392700.0'],
#  ['7.241', '5.49', '15.5', '686700.0'],
#  ['6.54', '8.65', '15.9', '346500.0'],
#  ['6.696', '7.18', '17.6', '501900.0'],
#  ['6.874', '4.61', '17.6', '655200.0'],
#  ['6.014', '10.53', '18.8', '367500.0'],
#  ['5.898', '12.67', '18.8', '361200.0'],
#  ['6.516', '6.36', '17.9', '485100.0'],
#  ['6.635', '5.99', '17.0', '514500.0'],
#  ['6.939', '5.89', '19.7', '558600.0'],
#  ['6.49', '5.98', '19.7', '480900.0'],
#  ['6.579', '5.49', '18.3', '506100.0'],
#  ['5.884', '7.79', '18.3', '390600.0'],
#  ['6.728', '4.5', '17.0', '632100.0'],
#  ['5.663', '8.05', '22.0', '382200.0'],
#  ['5.936', '5.57', '22.0', '432600.0'],
#  ['6.212', '17.6', '20.2', '373800.0'],
#  ['6.395', '13.27', '20.2', '455700.0'],
#  ['6.127', '11.48', '20.2', '476700.0'],
#  ['6.112', '12.67', '20.2', '474600.0'],
#  ['6.398', '7.79', '20.2', '525000.0'],
#  ['6.251', '14.19', '20.2', '417900.0'],
#  ['5.362', '10.19', '20.2', '436800.0'],
#  ['5.803', '14.64', '20.2', '352800.0'],
#  ['3.561', '7.12', '20.2', '577500.0'],
#  ['4.963', '14.0', '20.2', '459900.0'],
#  ['3.863', '13.33', '20.2', '485100.0'],
#  ['4.906', '34.77', '20.2', '289800.0'],
#  ['4.138', '37.97', '20.2', '289800.0'],
#  ['7.313', '13.44', '20.2', '315000.0'],
#  ['6.649', '23.24', '20.2', '291900.0'],
#  ['6.794', '21.24', '20.2', '279300.0'],
#  ['6.38', '23.69', '20.2', '275100.0'],
#  ['6.223', '21.78', '20.2', '214200.0'],
#  ['6.968', '17.21', '20.2', '218400.0'],
#  ['6.545', '21.08', '20.2', '228900.0'],
#  ['5.536', '23.6', '20.2', '237300.0'],
#  ['5.52', '24.56', '20.2', '258300.0'],
#  ['4.368', '30.63', '20.2', '184800.0'],
#  ['5.277', '30.81', '20.2', '151200.0'],
#  ['4.652', '28.28', '20.2', '220500.0'],
#  ['5.0', '31.99', '20.2', '155400.0'],
#  ['4.88', '30.62', '20.2', '214200.0'],
#  ['5.39', '20.85', '20.2', '241500.0'],
#  ['5.713', '17.11', '20.2', '317100.0'],
#  ['6.051', '18.76', '20.2', '487200.0'],
#  ['5.036', '25.68', '20.2', '203700.0'],
#  ['6.193', '15.17', '20.2', '289800.0'],
#  ['5.887', '16.35', '20.2', '266700.0'],
#  ['6.471', '17.12', '20.2', '275100.0'],
#  ['6.405', '19.37', '20.2', '262500.0'],
#  ['5.747', '19.92', '20.2', '178500.0'],
#  ['5.453', '30.59', '20.2', '105000.0'],
#  ['5.852', '29.97', '20.2', '132300.0'],
#  ['5.987', '26.77', '20.2', '117600.0'],
#  ['6.343', '20.32', '20.2', '151200.0'],
#  ['6.404', '20.31', '20.2', '254100.0'],
#  ['5.349', '19.77', '20.2', '174300.0'],
#  ['5.531', '27.38', '20.2', '178500.0'],
#  ['5.683', '22.98', '20.2', '105000.0'],
#  ['4.138', '23.34', '20.2', '249900.0'],
#  ['5.608', '12.13', '20.2', '585900.0'],
#  ['5.617', '26.4', '20.2', '361200.0'],
#  ['6.852', '19.78', '20.2', '577500.0'],
#  ['5.757', '10.11', '20.2', '315000.0'],
#  ['6.657', '21.22', '20.2', '361200.0'],
#  ['4.628', '34.37', '20.2', '375900.0'],
#  ['5.155', '20.08', '20.2', '342300.0'],
#  ['4.519', '36.98', '20.2', '147000.0'],
#  ['6.434', '29.05', '20.2', '151200.0'],
#  ['6.782', '25.79', '20.2', '157500.0'],
#  ['5.304', '26.64', '20.2', '218400.0'],
#  ['5.957', '20.62', '20.2', '184800.0'],
#  ['6.824', '22.74', '20.2', '176400.0'],
#  ['6.411', '15.02', '20.2', '350700.0'],
#  ['6.006', '15.7', '20.2', '298200.0'],
#  ['5.648', '14.1', '20.2', '436800.0'],
#  ['6.103', '23.29', '20.2', '281400.0'],
#  ['5.565', '17.16', '20.2', '245700.0'],
#  ['5.896', '24.39', '20.2', '174300.0'],
#  ['5.837', '15.69', '20.2', '214200.0'],
#  ['6.202', '14.52', '20.2', '228900.0'],
#  ['6.193', '21.52', '20.2', '231000.0'],
#  ['6.38', '24.08', '20.2', '199500.0'],
#  ['6.348', '17.64', '20.2', '304500.0'],
#  ['6.833', '19.69', '20.2', '296100.0'],
#  ['6.425', '12.03', '20.2', '338100.0'],
#  ['6.436', '16.22', '20.2', '300300.0'],
#  ['6.208', '15.17', '20.2', '245700.0'],
#  ['6.629', '23.27', '20.2', '281400.0'],
#  ['6.461', '18.05', '20.2', '201600.0'],
#  ['6.152', '26.45', '20.2', '182700.0'],
#  ['5.935', '34.02', '20.2', '176400.0'],
#  ['5.627', '22.88', '20.2', '268800.0'],
#  ['5.818', '22.11', '20.2', '220500.0'],
#  ['6.406', '19.52', '20.2', '359100.0'],
#  ['6.219', '16.59', '20.2', '386400.0'],
#  ['6.485', '18.85', '20.2', '323400.0'],
#  ['5.854', '23.79', '20.2', '226800.0'],
#  ['6.459', '23.98', '20.2', '247800.0'],
#  ['6.341', '17.79', '20.2', '312900.0'],
#  ['6.251', '16.44', '20.2', '264600.0'],
#  ['6.185', '18.13', '20.2', '296100.0'],
#  ['6.417', '19.31', '20.2', '273000.0'],
#  ['6.749', '17.44', '20.2', '281400.0'],
#  ['6.655', '17.73', '20.2', '319200.0'],
#  ['6.297', '17.27', '20.2', '338100.0'],
#  ['7.393', '16.74', '20.2', '373800.0'],
#  ['6.728', '18.71', '20.2', '312900.0'],
#  ['6.525', '18.13', '20.2', '296100.0'],
#  ['5.976', '19.01', '20.2', '266700.0'],
#  ['5.936', '16.94', '20.2', '283500.0'],
#  ['6.301', '16.23', '20.2', '312900.0'],
#  ['6.081', '14.7', '20.2', '420000.0'],
#  ['6.701', '16.42', '20.2', '344400.0'],
#  ['6.376', '14.65', '20.2', '371700.0'],
#  ['6.317', '13.99', '20.2', '409500.0'],
#  ['6.513', '10.29', '20.2', '424200.0'],
#  ['6.209', '13.22', '20.2', '449400.0'],
#  ['5.759', '14.13', '20.2', '417900.0'],
#  ['5.952', '17.15', '20.2', '399000.0'],
#  ['6.003', '21.32', '20.2', '401100.0'],
#  ['5.926', '18.13', '20.2', '401100.0'],
#  ['5.713', '14.76', '20.2', '422100.0'],
#  ['6.167', '16.29', '20.2', '417900.0'],
#  ['6.229', '12.87', '20.2', '411600.0'],
#  ['6.437', '14.36', '20.2', '487200.0'],
#  ['6.98', '11.66', '20.2', '625800.0'],
#  ['5.427', '18.14', '20.2', '289800.0'],
#  ['6.162', '24.1', '20.2', '279300.0'],
#  ['6.484', '18.68', '20.2', '350700.0'],
#  ['5.304', '24.91', '20.2', '252000.0'],
#  ['6.185', '18.03', '20.2', '306600.0'],
#  ['6.229', '13.11', '20.2', '449400.0'],
#  ['6.242', '10.74', '20.2', '483000.0'],
#  ['6.75', '7.74', '20.2', '497700.0'],
#  ['7.061', '7.01', '20.2', '525000.0'],
#  ['5.762', '10.42', '20.2', '457800.0'],
#  ['5.871', '13.34', '20.2', '432600.0'],
#  ['6.312', '10.58', '20.2', '445200.0'],
#  ['6.114', '14.98', '20.2', '401100.0'],
#  ['5.905', '11.45', '20.2', '432600.0'],
#  ['5.454', '18.06', '20.1', '319200.0'],
#  ['5.414', '23.97', '20.1', '147000.0'],
#  ['5.093', '29.68', '20.1', '170100.0'],
#  ['5.983', '18.07', '20.1', '285600.0'],
#  ['5.983', '13.35', '20.1', '422100.0'],
#  ['5.707', '12.01', '19.2', '457800.0'],
#  ['5.926', '13.59', '19.2', '514500.0'],
#  ['5.67', '17.6', '19.2', '485100.0'],
#  ['5.39', '21.14', '19.2', '413700.0'],
#  ['5.794', '14.1', '19.2', '384300.0'],
#  ['6.019', '12.92', '19.2', '445200.0'],
#  ['5.569', '15.1', '19.2', '367500.0'],
#  ['6.027', '14.33', '19.2', '352800.0'],
#  ['6.593', '9.67', '21.0', '470400.0'],
#  ['6.12', '9.08', '21.0', '432600.0'],
#  ['6.976', '5.64', '21.0', '501900.0'],
#  ['6.794', '6.48', '21.0', '462000.0'],
#  ['6.03', '7.88', '21.0', '249900.0']]

# %%
#  Or as dictionaries...
import csv
from io import StringIO   #  This lets us use a string in place of a file.

rows = []
for row in csv.DictReader(StringIO(response.text)):
    rows.append(row)
    print(row)
# Out:
# OrderedDict([('RM', '6.575'), ('LSTAT', '4.98'), ('PTRATIO', '15.3'), ('MDEV', '504000.0')])
# OrderedDict([('RM', '6.421'), ('LSTAT', '9.14'), ('PTRATIO', '17.8'), ('MDEV', '453600.0')])
# OrderedDict([('RM', '7.185'), ('LSTAT', '4.03'), ('PTRATIO', '17.8'), ('MDEV', '728700.0')])
# OrderedDict([('RM', '6.998'), ('LSTAT', '2.94'), ('PTRATIO', '18.7'), ('MDEV', '701400.0')])
# OrderedDict([('RM', '7.147'), ('LSTAT', '5.33'), ('PTRATIO', '18.7'), ('MDEV', '760200.0')])
# OrderedDict([('RM', '6.43'), ('LSTAT', '5.21'), ('PTRATIO', '18.7'), ('MDEV', '602700.0')])
# OrderedDict([('RM', '6.012'), ('LSTAT', '12.43'), ('PTRATIO', '15.2'), ('MDEV', '480900.0')])
# OrderedDict([('RM', '6.172'), ('LSTAT', '19.15'), ('PTRATIO', '15.2'), ('MDEV', '569100.0')])
# OrderedDict([('RM', '5.631'), ('LSTAT', '29.93'), ('PTRATIO', '15.2'), ('MDEV', '346500.0')])
# OrderedDict([('RM', '6.004'), ('LSTAT', '17.1'), ('PTRATIO', '15.2'), ('MDEV', '396900.0')])
# OrderedDict([('RM', '6.377'), ('LSTAT', '20.45'), ('PTRATIO', '15.2'), ('MDEV', '315000.0')])
# OrderedDict([('RM', '6.009'), ('LSTAT', '13.27'), ('PTRATIO', '15.2'), ('MDEV', '396900.0')])
# OrderedDict([('RM', '5.889'), ('LSTAT', '15.71'), ('PTRATIO', '15.2'), ('MDEV', '455700.0')])
# OrderedDict([('RM', '5.949'), ('LSTAT', '8.26'), ('PTRATIO', '21.0'), ('MDEV', '428400.0')])
# OrderedDict([('RM', '6.096'), ('LSTAT', '10.26'), ('PTRATIO', '21.0'), ('MDEV', '382200.0')])
# OrderedDict([('RM', '5.834'), ('LSTAT', '8.47'), ('PTRATIO', '21.0'), ('MDEV', '417900.0')])
# OrderedDict([('RM', '5.935'), ('LSTAT', '6.58'), ('PTRATIO', '21.0'), ('MDEV', '485100.0')])
# OrderedDict([('RM', '5.99'), ('LSTAT', '14.67'), ('PTRATIO', '21.0'), ('MDEV', '367500.0')])
# OrderedDict([('RM', '5.456'), ('LSTAT', '11.69'), ('PTRATIO', '21.0'), ('MDEV', '424200.0')])
# OrderedDict([('RM', '5.727'), ('LSTAT', '11.28'), ('PTRATIO', '21.0'), ('MDEV', '382200.0')])
# OrderedDict([('RM', '5.57'), ('LSTAT', '21.02'), ('PTRATIO', '21.0'), ('MDEV', '285600.0')])
# OrderedDict([('RM', '5.965'), ('LSTAT', '13.83'), ('PTRATIO', '21.0'), ('MDEV', '411600.0')])
# OrderedDict([('RM', '6.142'), ('LSTAT', '18.72'), ('PTRATIO', '21.0'), ('MDEV', '319200.0')])
# OrderedDict([('RM', '5.813'), ('LSTAT', '19.88'), ('PTRATIO', '21.0'), ('MDEV', '304500.0')])
# OrderedDict([('RM', '5.924'), ('LSTAT', '16.3'), ('PTRATIO', '21.0'), ('MDEV', '327600.0')])
# OrderedDict([('RM', '5.599'), ('LSTAT', '16.51'), ('PTRATIO', '21.0'), ('MDEV', '291900.0')])
# OrderedDict([('RM', '5.813'), ('LSTAT', '14.81'), ('PTRATIO', '21.0'), ('MDEV', '348600.0')])
# OrderedDict([('RM', '6.047'), ('LSTAT', '17.28'), ('PTRATIO', '21.0'), ('MDEV', '310800.0')])
# OrderedDict([('RM', '6.495'), ('LSTAT', '12.8'), ('PTRATIO', '21.0'), ('MDEV', '386400.0')])
# OrderedDict([('RM', '6.674'), ('LSTAT', '11.98'), ('PTRATIO', '21.0'), ('MDEV', '441000.0')])
# OrderedDict([('RM', '5.713'), ('LSTAT', '22.6'), ('PTRATIO', '21.0'), ('MDEV', '266700.0')])
# OrderedDict([('RM', '6.072'), ('LSTAT', '13.04'), ('PTRATIO', '21.0'), ('MDEV', '304500.0')])
# OrderedDict([('RM', '5.95'), ('LSTAT', '27.71'), ('PTRATIO', '21.0'), ('MDEV', '277200.0')])
# OrderedDict([('RM', '5.701'), ('LSTAT', '18.35'), ('PTRATIO', '21.0'), ('MDEV', '275100.0')])
# OrderedDict([('RM', '6.096'), ('LSTAT', '20.34'), ('PTRATIO', '21.0'), ('MDEV', '283500.0')])
# OrderedDict([('RM', '5.933'), ('LSTAT', '9.68'), ('PTRATIO', '19.2'), ('MDEV', '396900.0')])
# OrderedDict([('RM', '5.841'), ('LSTAT', '11.41'), ('PTRATIO', '19.2'), ('MDEV', '420000.0')])
# OrderedDict([('RM', '5.85'), ('LSTAT', '8.77'), ('PTRATIO', '19.2'), ('MDEV', '441000.0')])
# OrderedDict([('RM', '5.966'), ('LSTAT', '10.13'), ('PTRATIO', '19.2'), ('MDEV', '518700.0')])
# OrderedDict([('RM', '6.595'), ('LSTAT', '4.32'), ('PTRATIO', '18.3'), ('MDEV', '646800.0')])
# OrderedDict([('RM', '7.024'), ('LSTAT', '1.98'), ('PTRATIO', '18.3'), ('MDEV', '732900.0')])
# OrderedDict([('RM', '6.77'), ('LSTAT', '4.84'), ('PTRATIO', '17.9'), ('MDEV', '558600.0')])
# OrderedDict([('RM', '6.169'), ('LSTAT', '5.81'), ('PTRATIO', '17.9'), ('MDEV', '531300.0')])
# OrderedDict([('RM', '6.211'), ('LSTAT', '7.44'), ('PTRATIO', '17.9'), ('MDEV', '518700.0')])
# OrderedDict([('RM', '6.069'), ('LSTAT', '9.55'), ('PTRATIO', '17.9'), ('MDEV', '445200.0')])
# OrderedDict([('RM', '5.682'), ('LSTAT', '10.21'), ('PTRATIO', '17.9'), ('MDEV', '405300.0')])
# OrderedDict([('RM', '5.786'), ('LSTAT', '14.15'), ('PTRATIO', '17.9'), ('MDEV', '420000.0')])
# OrderedDict([('RM', '6.03'), ('LSTAT', '18.8'), ('PTRATIO', '17.9'), ('MDEV', '348600.0')])
# OrderedDict([('RM', '5.399'), ('LSTAT', '30.81'), ('PTRATIO', '17.9'), ('MDEV', '302400.0')])
# OrderedDict([('RM', '5.602'), ('LSTAT', '16.2'), ('PTRATIO', '17.9'), ('MDEV', '407400.0')])
# OrderedDict([('RM', '5.963'), ('LSTAT', '13.45'), ('PTRATIO', '16.8'), ('MDEV', '413700.0')])
# OrderedDict([('RM', '6.115'), ('LSTAT', '9.43'), ('PTRATIO', '16.8'), ('MDEV', '430500.0')])
# OrderedDict([('RM', '6.511'), ('LSTAT', '5.28'), ('PTRATIO', '16.8'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '5.998'), ('LSTAT', '8.43'), ('PTRATIO', '16.8'), ('MDEV', '491400.0')])
# OrderedDict([('RM', '5.888'), ('LSTAT', '14.8'), ('PTRATIO', '21.1'), ('MDEV', '396900.0')])
# OrderedDict([('RM', '7.249'), ('LSTAT', '4.81'), ('PTRATIO', '17.9'), ('MDEV', '743400.0')])
# OrderedDict([('RM', '6.383'), ('LSTAT', '5.77'), ('PTRATIO', '17.3'), ('MDEV', '518700.0')])
# OrderedDict([('RM', '6.816'), ('LSTAT', '3.95'), ('PTRATIO', '15.1'), ('MDEV', '663600.0')])
# OrderedDict([('RM', '6.145'), ('LSTAT', '6.86'), ('PTRATIO', '19.7'), ('MDEV', '489300.0')])
# OrderedDict([('RM', '5.927'), ('LSTAT', '9.22'), ('PTRATIO', '19.7'), ('MDEV', '411600.0')])
# OrderedDict([('RM', '5.741'), ('LSTAT', '13.15'), ('PTRATIO', '19.7'), ('MDEV', '392700.0')])
# OrderedDict([('RM', '5.966'), ('LSTAT', '14.44'), ('PTRATIO', '19.7'), ('MDEV', '336000.0')])
# OrderedDict([('RM', '6.456'), ('LSTAT', '6.73'), ('PTRATIO', '19.7'), ('MDEV', '466200.0')])
# OrderedDict([('RM', '6.762'), ('LSTAT', '9.5'), ('PTRATIO', '19.7'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '7.104'), ('LSTAT', '8.05'), ('PTRATIO', '18.6'), ('MDEV', '693000.0')])
# OrderedDict([('RM', '6.29'), ('LSTAT', '4.67'), ('PTRATIO', '16.1'), ('MDEV', '493500.0')])
# OrderedDict([('RM', '5.787'), ('LSTAT', '10.24'), ('PTRATIO', '16.1'), ('MDEV', '407400.0')])
# OrderedDict([('RM', '5.878'), ('LSTAT', '8.1'), ('PTRATIO', '18.9'), ('MDEV', '462000.0')])
# OrderedDict([('RM', '5.594'), ('LSTAT', '13.09'), ('PTRATIO', '18.9'), ('MDEV', '365400.0')])
# OrderedDict([('RM', '5.885'), ('LSTAT', '8.79'), ('PTRATIO', '18.9'), ('MDEV', '438900.0')])
# OrderedDict([('RM', '6.417'), ('LSTAT', '6.72'), ('PTRATIO', '19.2'), ('MDEV', '508200.0')])
# OrderedDict([('RM', '5.961'), ('LSTAT', '9.88'), ('PTRATIO', '19.2'), ('MDEV', '455700.0')])
# OrderedDict([('RM', '6.065'), ('LSTAT', '5.52'), ('PTRATIO', '19.2'), ('MDEV', '478800.0')])
# OrderedDict([('RM', '6.245'), ('LSTAT', '7.54'), ('PTRATIO', '19.2'), ('MDEV', '491400.0')])
# OrderedDict([('RM', '6.273'), ('LSTAT', '6.78'), ('PTRATIO', '18.7'), ('MDEV', '506100.0')])
# OrderedDict([('RM', '6.286'), ('LSTAT', '8.94'), ('PTRATIO', '18.7'), ('MDEV', '449400.0')])
# OrderedDict([('RM', '6.279'), ('LSTAT', '11.97'), ('PTRATIO', '18.7'), ('MDEV', '420000.0')])
# OrderedDict([('RM', '6.14'), ('LSTAT', '10.27'), ('PTRATIO', '18.7'), ('MDEV', '436800.0')])
# OrderedDict([('RM', '6.232'), ('LSTAT', '12.34'), ('PTRATIO', '18.7'), ('MDEV', '445200.0')])
# OrderedDict([('RM', '5.874'), ('LSTAT', '9.1'), ('PTRATIO', '18.7'), ('MDEV', '426300.0')])
# OrderedDict([('RM', '6.727'), ('LSTAT', '5.29'), ('PTRATIO', '19.0'), ('MDEV', '588000.0')])
# OrderedDict([('RM', '6.619'), ('LSTAT', '7.22'), ('PTRATIO', '19.0'), ('MDEV', '501900.0')])
# OrderedDict([('RM', '6.302'), ('LSTAT', '6.72'), ('PTRATIO', '19.0'), ('MDEV', '520800.0')])
# OrderedDict([('RM', '6.167'), ('LSTAT', '7.51'), ('PTRATIO', '19.0'), ('MDEV', '480900.0')])
# OrderedDict([('RM', '6.389'), ('LSTAT', '9.62'), ('PTRATIO', '18.5'), ('MDEV', '501900.0')])
# OrderedDict([('RM', '6.63'), ('LSTAT', '6.53'), ('PTRATIO', '18.5'), ('MDEV', '558600.0')])
# OrderedDict([('RM', '6.015'), ('LSTAT', '12.86'), ('PTRATIO', '18.5'), ('MDEV', '472500.0')])
# OrderedDict([('RM', '6.121'), ('LSTAT', '8.44'), ('PTRATIO', '18.5'), ('MDEV', '466200.0')])
# OrderedDict([('RM', '7.007'), ('LSTAT', '5.5'), ('PTRATIO', '17.8'), ('MDEV', '495600.0')])
# OrderedDict([('RM', '7.079'), ('LSTAT', '5.7'), ('PTRATIO', '17.8'), ('MDEV', '602700.0')])
# OrderedDict([('RM', '6.417'), ('LSTAT', '8.81'), ('PTRATIO', '17.8'), ('MDEV', '474600.0')])
# OrderedDict([('RM', '6.405'), ('LSTAT', '8.2'), ('PTRATIO', '17.8'), ('MDEV', '462000.0')])
# OrderedDict([('RM', '6.442'), ('LSTAT', '8.16'), ('PTRATIO', '18.2'), ('MDEV', '480900.0')])
# OrderedDict([('RM', '6.211'), ('LSTAT', '6.21'), ('PTRATIO', '18.2'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '6.249'), ('LSTAT', '10.59'), ('PTRATIO', '18.2'), ('MDEV', '432600.0')])
# OrderedDict([('RM', '6.625'), ('LSTAT', '6.65'), ('PTRATIO', '18.0'), ('MDEV', '596400.0')])
# OrderedDict([('RM', '6.163'), ('LSTAT', '11.34'), ('PTRATIO', '18.0'), ('MDEV', '449400.0')])
# OrderedDict([('RM', '8.069'), ('LSTAT', '4.21'), ('PTRATIO', '18.0'), ('MDEV', '812700.0')])
# OrderedDict([('RM', '7.82'), ('LSTAT', '3.57'), ('PTRATIO', '18.0'), ('MDEV', '919800.0')])
# OrderedDict([('RM', '7.416'), ('LSTAT', '6.19'), ('PTRATIO', '18.0'), ('MDEV', '697200.0')])
# OrderedDict([('RM', '6.727'), ('LSTAT', '9.42'), ('PTRATIO', '20.9'), ('MDEV', '577500.0')])
# OrderedDict([('RM', '6.781'), ('LSTAT', '7.67'), ('PTRATIO', '20.9'), ('MDEV', '556500.0')])
# OrderedDict([('RM', '6.405'), ('LSTAT', '10.63'), ('PTRATIO', '20.9'), ('MDEV', '390600.0')])
# OrderedDict([('RM', '6.137'), ('LSTAT', '13.44'), ('PTRATIO', '20.9'), ('MDEV', '405300.0')])
# OrderedDict([('RM', '6.167'), ('LSTAT', '12.33'), ('PTRATIO', '20.9'), ('MDEV', '422100.0')])
# OrderedDict([('RM', '5.851'), ('LSTAT', '16.47'), ('PTRATIO', '20.9'), ('MDEV', '409500.0')])
# OrderedDict([('RM', '5.836'), ('LSTAT', '18.66'), ('PTRATIO', '20.9'), ('MDEV', '409500.0')])
# OrderedDict([('RM', '6.127'), ('LSTAT', '14.09'), ('PTRATIO', '20.9'), ('MDEV', '428400.0')])
# OrderedDict([('RM', '6.474'), ('LSTAT', '12.27'), ('PTRATIO', '20.9'), ('MDEV', '415800.0')])
# OrderedDict([('RM', '6.229'), ('LSTAT', '15.55'), ('PTRATIO', '20.9'), ('MDEV', '407400.0')])
# OrderedDict([('RM', '6.195'), ('LSTAT', '13.0'), ('PTRATIO', '20.9'), ('MDEV', '455700.0')])
# OrderedDict([('RM', '6.715'), ('LSTAT', '10.16'), ('PTRATIO', '17.8'), ('MDEV', '478800.0')])
# OrderedDict([('RM', '5.913'), ('LSTAT', '16.21'), ('PTRATIO', '17.8'), ('MDEV', '394800.0')])
# OrderedDict([('RM', '6.092'), ('LSTAT', '17.09'), ('PTRATIO', '17.8'), ('MDEV', '392700.0')])
# OrderedDict([('RM', '6.254'), ('LSTAT', '10.45'), ('PTRATIO', '17.8'), ('MDEV', '388500.0')])
# OrderedDict([('RM', '5.928'), ('LSTAT', '15.76'), ('PTRATIO', '17.8'), ('MDEV', '384300.0')])
# OrderedDict([('RM', '6.176'), ('LSTAT', '12.04'), ('PTRATIO', '17.8'), ('MDEV', '445200.0')])
# OrderedDict([('RM', '6.021'), ('LSTAT', '10.3'), ('PTRATIO', '17.8'), ('MDEV', '403200.0')])
# OrderedDict([('RM', '5.872'), ('LSTAT', '15.37'), ('PTRATIO', '17.8'), ('MDEV', '428400.0')])
# OrderedDict([('RM', '5.731'), ('LSTAT', '13.61'), ('PTRATIO', '17.8'), ('MDEV', '405300.0')])
# OrderedDict([('RM', '5.87'), ('LSTAT', '14.37'), ('PTRATIO', '19.1'), ('MDEV', '462000.0')])
# OrderedDict([('RM', '6.004'), ('LSTAT', '14.27'), ('PTRATIO', '19.1'), ('MDEV', '426300.0')])
# OrderedDict([('RM', '5.961'), ('LSTAT', '17.93'), ('PTRATIO', '19.1'), ('MDEV', '430500.0')])
# OrderedDict([('RM', '5.856'), ('LSTAT', '25.41'), ('PTRATIO', '19.1'), ('MDEV', '363300.0')])
# OrderedDict([('RM', '5.879'), ('LSTAT', '17.58'), ('PTRATIO', '19.1'), ('MDEV', '394800.0')])
# OrderedDict([('RM', '5.986'), ('LSTAT', '14.81'), ('PTRATIO', '19.1'), ('MDEV', '449400.0')])
# OrderedDict([('RM', '5.613'), ('LSTAT', '27.26'), ('PTRATIO', '19.1'), ('MDEV', '329700.0')])
# OrderedDict([('RM', '5.693'), ('LSTAT', '17.19'), ('PTRATIO', '21.2'), ('MDEV', '340200.0')])
# OrderedDict([('RM', '6.431'), ('LSTAT', '15.39'), ('PTRATIO', '21.2'), ('MDEV', '378000.0')])
# OrderedDict([('RM', '5.637'), ('LSTAT', '18.34'), ('PTRATIO', '21.2'), ('MDEV', '300300.0')])
# OrderedDict([('RM', '6.458'), ('LSTAT', '12.6'), ('PTRATIO', '21.2'), ('MDEV', '403200.0')])
# OrderedDict([('RM', '6.326'), ('LSTAT', '12.26'), ('PTRATIO', '21.2'), ('MDEV', '411600.0')])
# OrderedDict([('RM', '6.372'), ('LSTAT', '11.12'), ('PTRATIO', '21.2'), ('MDEV', '483000.0')])
# OrderedDict([('RM', '5.822'), ('LSTAT', '15.03'), ('PTRATIO', '21.2'), ('MDEV', '386400.0')])
# OrderedDict([('RM', '5.757'), ('LSTAT', '17.31'), ('PTRATIO', '21.2'), ('MDEV', '327600.0')])
# OrderedDict([('RM', '6.335'), ('LSTAT', '16.96'), ('PTRATIO', '21.2'), ('MDEV', '380100.0')])
# OrderedDict([('RM', '5.942'), ('LSTAT', '16.9'), ('PTRATIO', '21.2'), ('MDEV', '365400.0')])
# OrderedDict([('RM', '6.454'), ('LSTAT', '14.59'), ('PTRATIO', '21.2'), ('MDEV', '359100.0')])
# OrderedDict([('RM', '5.857'), ('LSTAT', '21.32'), ('PTRATIO', '21.2'), ('MDEV', '279300.0')])
# OrderedDict([('RM', '6.151'), ('LSTAT', '18.46'), ('PTRATIO', '21.2'), ('MDEV', '373800.0')])
# OrderedDict([('RM', '6.174'), ('LSTAT', '24.16'), ('PTRATIO', '21.2'), ('MDEV', '294000.0')])
# OrderedDict([('RM', '5.019'), ('LSTAT', '34.41'), ('PTRATIO', '21.2'), ('MDEV', '302400.0')])
# OrderedDict([('RM', '5.403'), ('LSTAT', '26.82'), ('PTRATIO', '14.7'), ('MDEV', '281400.0')])
# OrderedDict([('RM', '5.468'), ('LSTAT', '26.42'), ('PTRATIO', '14.7'), ('MDEV', '327600.0')])
# OrderedDict([('RM', '4.903'), ('LSTAT', '29.29'), ('PTRATIO', '14.7'), ('MDEV', '247800.0')])
# OrderedDict([('RM', '6.13'), ('LSTAT', '27.8'), ('PTRATIO', '14.7'), ('MDEV', '289800.0')])
# OrderedDict([('RM', '5.628'), ('LSTAT', '16.65'), ('PTRATIO', '14.7'), ('MDEV', '327600.0')])
# OrderedDict([('RM', '4.926'), ('LSTAT', '29.53'), ('PTRATIO', '14.7'), ('MDEV', '306600.0')])
# OrderedDict([('RM', '5.186'), ('LSTAT', '28.32'), ('PTRATIO', '14.7'), ('MDEV', '373800.0')])
# OrderedDict([('RM', '5.597'), ('LSTAT', '21.45'), ('PTRATIO', '14.7'), ('MDEV', '323400.0')])
# OrderedDict([('RM', '6.122'), ('LSTAT', '14.1'), ('PTRATIO', '14.7'), ('MDEV', '451500.0')])
# OrderedDict([('RM', '5.404'), ('LSTAT', '13.28'), ('PTRATIO', '14.7'), ('MDEV', '411600.0')])
# OrderedDict([('RM', '5.012'), ('LSTAT', '12.12'), ('PTRATIO', '14.7'), ('MDEV', '321300.0')])
# OrderedDict([('RM', '5.709'), ('LSTAT', '15.79'), ('PTRATIO', '14.7'), ('MDEV', '407400.0')])
# OrderedDict([('RM', '6.129'), ('LSTAT', '15.12'), ('PTRATIO', '14.7'), ('MDEV', '357000.0')])
# OrderedDict([('RM', '6.152'), ('LSTAT', '15.02'), ('PTRATIO', '14.7'), ('MDEV', '327600.0')])
# OrderedDict([('RM', '5.272'), ('LSTAT', '16.14'), ('PTRATIO', '14.7'), ('MDEV', '275100.0')])
# OrderedDict([('RM', '6.943'), ('LSTAT', '4.59'), ('PTRATIO', '14.7'), ('MDEV', '867300.0')])
# OrderedDict([('RM', '6.066'), ('LSTAT', '6.43'), ('PTRATIO', '14.7'), ('MDEV', '510300.0')])
# OrderedDict([('RM', '6.51'), ('LSTAT', '7.39'), ('PTRATIO', '14.7'), ('MDEV', '489300.0')])
# OrderedDict([('RM', '6.25'), ('LSTAT', '5.5'), ('PTRATIO', '14.7'), ('MDEV', '567000.0')])
# OrderedDict([('RM', '5.854'), ('LSTAT', '11.64'), ('PTRATIO', '14.7'), ('MDEV', '476700.0')])
# OrderedDict([('RM', '6.101'), ('LSTAT', '9.81'), ('PTRATIO', '14.7'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '5.877'), ('LSTAT', '12.14'), ('PTRATIO', '14.7'), ('MDEV', '499800.0')])
# OrderedDict([('RM', '6.319'), ('LSTAT', '11.1'), ('PTRATIO', '14.7'), ('MDEV', '499800.0')])
# OrderedDict([('RM', '6.402'), ('LSTAT', '11.32'), ('PTRATIO', '14.7'), ('MDEV', '468300.0')])
# OrderedDict([('RM', '5.875'), ('LSTAT', '14.43'), ('PTRATIO', '14.7'), ('MDEV', '365400.0')])
# OrderedDict([('RM', '5.88'), ('LSTAT', '12.03'), ('PTRATIO', '14.7'), ('MDEV', '401100.0')])
# OrderedDict([('RM', '5.572'), ('LSTAT', '14.69'), ('PTRATIO', '16.6'), ('MDEV', '485100.0')])
# OrderedDict([('RM', '6.416'), ('LSTAT', '9.04'), ('PTRATIO', '16.6'), ('MDEV', '495600.0')])
# OrderedDict([('RM', '5.859'), ('LSTAT', '9.64'), ('PTRATIO', '16.6'), ('MDEV', '474600.0')])
# OrderedDict([('RM', '6.546'), ('LSTAT', '5.33'), ('PTRATIO', '16.6'), ('MDEV', '617400.0')])
# OrderedDict([('RM', '6.02'), ('LSTAT', '10.11'), ('PTRATIO', '16.6'), ('MDEV', '487200.0')])
# OrderedDict([('RM', '6.315'), ('LSTAT', '6.29'), ('PTRATIO', '16.6'), ('MDEV', '516600.0')])
# OrderedDict([('RM', '6.86'), ('LSTAT', '6.92'), ('PTRATIO', '16.6'), ('MDEV', '627900.0')])
# OrderedDict([('RM', '6.98'), ('LSTAT', '5.04'), ('PTRATIO', '17.8'), ('MDEV', '781200.0')])
# OrderedDict([('RM', '7.765'), ('LSTAT', '7.56'), ('PTRATIO', '17.8'), ('MDEV', '835800.0')])
# OrderedDict([('RM', '6.144'), ('LSTAT', '9.45'), ('PTRATIO', '17.8'), ('MDEV', '760200.0')])
# OrderedDict([('RM', '7.155'), ('LSTAT', '4.82'), ('PTRATIO', '17.8'), ('MDEV', '795900.0')])
# OrderedDict([('RM', '6.563'), ('LSTAT', '5.68'), ('PTRATIO', '17.8'), ('MDEV', '682500.0')])
# OrderedDict([('RM', '5.604'), ('LSTAT', '13.98'), ('PTRATIO', '17.8'), ('MDEV', '554400.0')])
# OrderedDict([('RM', '6.153'), ('LSTAT', '13.15'), ('PTRATIO', '17.8'), ('MDEV', '621600.0')])
# OrderedDict([('RM', '6.782'), ('LSTAT', '6.68'), ('PTRATIO', '15.2'), ('MDEV', '672000.0')])
# OrderedDict([('RM', '6.556'), ('LSTAT', '4.56'), ('PTRATIO', '15.2'), ('MDEV', '625800.0')])
# OrderedDict([('RM', '7.185'), ('LSTAT', '5.39'), ('PTRATIO', '15.2'), ('MDEV', '732900.0')])
# OrderedDict([('RM', '6.951'), ('LSTAT', '5.1'), ('PTRATIO', '15.2'), ('MDEV', '777000.0')])
# OrderedDict([('RM', '6.739'), ('LSTAT', '4.69'), ('PTRATIO', '15.2'), ('MDEV', '640500.0')])
# OrderedDict([('RM', '7.178'), ('LSTAT', '2.87'), ('PTRATIO', '15.2'), ('MDEV', '764400.0')])
# OrderedDict([('RM', '6.8'), ('LSTAT', '5.03'), ('PTRATIO', '15.6'), ('MDEV', '653100.0')])
# OrderedDict([('RM', '6.604'), ('LSTAT', '4.38'), ('PTRATIO', '15.6'), ('MDEV', '611100.0')])
# OrderedDict([('RM', '7.287'), ('LSTAT', '4.08'), ('PTRATIO', '12.6'), ('MDEV', '699300.0')])
# OrderedDict([('RM', '7.107'), ('LSTAT', '8.61'), ('PTRATIO', '12.6'), ('MDEV', '636300.0')])
# OrderedDict([('RM', '7.274'), ('LSTAT', '6.62'), ('PTRATIO', '12.6'), ('MDEV', '726600.0')])
# OrderedDict([('RM', '6.975'), ('LSTAT', '4.56'), ('PTRATIO', '17.0'), ('MDEV', '732900.0')])
# OrderedDict([('RM', '7.135'), ('LSTAT', '4.45'), ('PTRATIO', '17.0'), ('MDEV', '690900.0')])
# OrderedDict([('RM', '6.162'), ('LSTAT', '7.43'), ('PTRATIO', '14.7'), ('MDEV', '506100.0')])
# OrderedDict([('RM', '7.61'), ('LSTAT', '3.11'), ('PTRATIO', '14.7'), ('MDEV', '888300.0')])
# OrderedDict([('RM', '7.853'), ('LSTAT', '3.81'), ('PTRATIO', '14.7'), ('MDEV', '1018500.0')])
# OrderedDict([('RM', '5.891'), ('LSTAT', '10.87'), ('PTRATIO', '18.6'), ('MDEV', '474600.0')])
# OrderedDict([('RM', '6.326'), ('LSTAT', '10.97'), ('PTRATIO', '18.6'), ('MDEV', '512400.0')])
# OrderedDict([('RM', '5.783'), ('LSTAT', '18.06'), ('PTRATIO', '18.6'), ('MDEV', '472500.0')])
# OrderedDict([('RM', '6.064'), ('LSTAT', '14.66'), ('PTRATIO', '18.6'), ('MDEV', '512400.0')])
# OrderedDict([('RM', '5.344'), ('LSTAT', '23.09'), ('PTRATIO', '18.6'), ('MDEV', '420000.0')])
# OrderedDict([('RM', '5.96'), ('LSTAT', '17.27'), ('PTRATIO', '18.6'), ('MDEV', '455700.0')])
# OrderedDict([('RM', '5.404'), ('LSTAT', '23.98'), ('PTRATIO', '18.6'), ('MDEV', '405300.0')])
# OrderedDict([('RM', '5.807'), ('LSTAT', '16.03'), ('PTRATIO', '18.6'), ('MDEV', '470400.0')])
# OrderedDict([('RM', '6.375'), ('LSTAT', '9.38'), ('PTRATIO', '18.6'), ('MDEV', '590100.0')])
# OrderedDict([('RM', '5.412'), ('LSTAT', '29.55'), ('PTRATIO', '18.6'), ('MDEV', '497700.0')])
# OrderedDict([('RM', '6.182'), ('LSTAT', '9.47'), ('PTRATIO', '18.6'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '5.888'), ('LSTAT', '13.51'), ('PTRATIO', '16.4'), ('MDEV', '489300.0')])
# OrderedDict([('RM', '6.642'), ('LSTAT', '9.69'), ('PTRATIO', '16.4'), ('MDEV', '602700.0')])
# OrderedDict([('RM', '5.951'), ('LSTAT', '17.92'), ('PTRATIO', '16.4'), ('MDEV', '451500.0')])
# OrderedDict([('RM', '6.373'), ('LSTAT', '10.5'), ('PTRATIO', '16.4'), ('MDEV', '483000.0')])
# OrderedDict([('RM', '6.951'), ('LSTAT', '9.71'), ('PTRATIO', '17.4'), ('MDEV', '560700.0')])
# OrderedDict([('RM', '6.164'), ('LSTAT', '21.46'), ('PTRATIO', '17.4'), ('MDEV', '455700.0')])
# OrderedDict([('RM', '6.879'), ('LSTAT', '9.93'), ('PTRATIO', '17.4'), ('MDEV', '577500.0')])
# OrderedDict([('RM', '6.618'), ('LSTAT', '7.6'), ('PTRATIO', '17.4'), ('MDEV', '632100.0')])
# OrderedDict([('RM', '8.266'), ('LSTAT', '4.14'), ('PTRATIO', '17.4'), ('MDEV', '940800.0')])
# OrderedDict([('RM', '8.04'), ('LSTAT', '3.13'), ('PTRATIO', '17.4'), ('MDEV', '789600.0')])
# OrderedDict([('RM', '7.163'), ('LSTAT', '6.36'), ('PTRATIO', '17.4'), ('MDEV', '663600.0')])
# OrderedDict([('RM', '7.686'), ('LSTAT', '3.92'), ('PTRATIO', '17.4'), ('MDEV', '980700.0')])
# OrderedDict([('RM', '6.552'), ('LSTAT', '3.76'), ('PTRATIO', '17.4'), ('MDEV', '661500.0')])
# OrderedDict([('RM', '5.981'), ('LSTAT', '11.65'), ('PTRATIO', '17.4'), ('MDEV', '510300.0')])
# OrderedDict([('RM', '7.412'), ('LSTAT', '5.25'), ('PTRATIO', '17.4'), ('MDEV', '665700.0')])
# OrderedDict([('RM', '8.337'), ('LSTAT', '2.47'), ('PTRATIO', '17.4'), ('MDEV', '875700.0')])
# OrderedDict([('RM', '8.247'), ('LSTAT', '3.95'), ('PTRATIO', '17.4'), ('MDEV', '1014300.0')])
# OrderedDict([('RM', '6.726'), ('LSTAT', '8.05'), ('PTRATIO', '17.4'), ('MDEV', '609000.0')])
# OrderedDict([('RM', '6.086'), ('LSTAT', '10.88'), ('PTRATIO', '17.4'), ('MDEV', '504000.0')])
# OrderedDict([('RM', '6.631'), ('LSTAT', '9.54'), ('PTRATIO', '17.4'), ('MDEV', '527100.0')])
# OrderedDict([('RM', '7.358'), ('LSTAT', '4.73'), ('PTRATIO', '17.4'), ('MDEV', '661500.0')])
# OrderedDict([('RM', '6.481'), ('LSTAT', '6.36'), ('PTRATIO', '16.6'), ('MDEV', '497700.0')])
# OrderedDict([('RM', '6.606'), ('LSTAT', '7.37'), ('PTRATIO', '16.6'), ('MDEV', '489300.0')])
# OrderedDict([('RM', '6.897'), ('LSTAT', '11.38'), ('PTRATIO', '16.6'), ('MDEV', '462000.0')])
# OrderedDict([('RM', '6.095'), ('LSTAT', '12.4'), ('PTRATIO', '16.6'), ('MDEV', '422100.0')])
# OrderedDict([('RM', '6.358'), ('LSTAT', '11.22'), ('PTRATIO', '16.6'), ('MDEV', '466200.0')])
# OrderedDict([('RM', '6.393'), ('LSTAT', '5.19'), ('PTRATIO', '16.6'), ('MDEV', '497700.0')])
# OrderedDict([('RM', '5.593'), ('LSTAT', '12.5'), ('PTRATIO', '19.1'), ('MDEV', '369600.0')])
# OrderedDict([('RM', '5.605'), ('LSTAT', '18.46'), ('PTRATIO', '19.1'), ('MDEV', '388500.0')])
# OrderedDict([('RM', '6.108'), ('LSTAT', '9.16'), ('PTRATIO', '19.1'), ('MDEV', '510300.0')])
# OrderedDict([('RM', '6.226'), ('LSTAT', '10.15'), ('PTRATIO', '19.1'), ('MDEV', '430500.0')])
# OrderedDict([('RM', '6.433'), ('LSTAT', '9.52'), ('PTRATIO', '19.1'), ('MDEV', '514500.0')])
# OrderedDict([('RM', '6.718'), ('LSTAT', '6.56'), ('PTRATIO', '19.1'), ('MDEV', '550200.0')])
# OrderedDict([('RM', '6.487'), ('LSTAT', '5.9'), ('PTRATIO', '19.1'), ('MDEV', '512400.0')])
# OrderedDict([('RM', '6.438'), ('LSTAT', '3.59'), ('PTRATIO', '19.1'), ('MDEV', '520800.0')])
# OrderedDict([('RM', '6.957'), ('LSTAT', '3.53'), ('PTRATIO', '19.1'), ('MDEV', '621600.0')])
# OrderedDict([('RM', '8.259'), ('LSTAT', '3.54'), ('PTRATIO', '19.1'), ('MDEV', '898800.0')])
# OrderedDict([('RM', '6.108'), ('LSTAT', '6.57'), ('PTRATIO', '16.4'), ('MDEV', '459900.0')])
# OrderedDict([('RM', '5.876'), ('LSTAT', '9.25'), ('PTRATIO', '16.4'), ('MDEV', '438900.0')])
# OrderedDict([('RM', '7.454'), ('LSTAT', '3.11'), ('PTRATIO', '15.9'), ('MDEV', '924000.0')])
# OrderedDict([('RM', '7.333'), ('LSTAT', '7.79'), ('PTRATIO', '13.0'), ('MDEV', '756000.0')])
# OrderedDict([('RM', '6.842'), ('LSTAT', '6.9'), ('PTRATIO', '13.0'), ('MDEV', '632100.0')])
# OrderedDict([('RM', '7.203'), ('LSTAT', '9.59'), ('PTRATIO', '13.0'), ('MDEV', '709800.0')])
# OrderedDict([('RM', '7.52'), ('LSTAT', '7.26'), ('PTRATIO', '13.0'), ('MDEV', '905100.0')])
# OrderedDict([('RM', '8.398'), ('LSTAT', '5.91'), ('PTRATIO', '13.0'), ('MDEV', '1024800.0')])
# OrderedDict([('RM', '7.327'), ('LSTAT', '11.25'), ('PTRATIO', '13.0'), ('MDEV', '651000.0')])
# OrderedDict([('RM', '7.206'), ('LSTAT', '8.1'), ('PTRATIO', '13.0'), ('MDEV', '766500.0')])
# OrderedDict([('RM', '5.56'), ('LSTAT', '10.45'), ('PTRATIO', '13.0'), ('MDEV', '478800.0')])
# OrderedDict([('RM', '7.014'), ('LSTAT', '14.79'), ('PTRATIO', '13.0'), ('MDEV', '644700.0')])
# OrderedDict([('RM', '7.47'), ('LSTAT', '3.16'), ('PTRATIO', '13.0'), ('MDEV', '913500.0')])
# OrderedDict([('RM', '5.92'), ('LSTAT', '13.65'), ('PTRATIO', '18.6'), ('MDEV', '434700.0')])
# OrderedDict([('RM', '5.856'), ('LSTAT', '13.0'), ('PTRATIO', '18.6'), ('MDEV', '443100.0')])
# OrderedDict([('RM', '6.24'), ('LSTAT', '6.59'), ('PTRATIO', '18.6'), ('MDEV', '529200.0')])
# OrderedDict([('RM', '6.538'), ('LSTAT', '7.73'), ('PTRATIO', '18.6'), ('MDEV', '512400.0')])
# OrderedDict([('RM', '7.691'), ('LSTAT', '6.58'), ('PTRATIO', '18.6'), ('MDEV', '739200.0')])
# OrderedDict([('RM', '6.758'), ('LSTAT', '3.53'), ('PTRATIO', '17.6'), ('MDEV', '680400.0')])
# OrderedDict([('RM', '6.854'), ('LSTAT', '2.98'), ('PTRATIO', '17.6'), ('MDEV', '672000.0')])
# OrderedDict([('RM', '7.267'), ('LSTAT', '6.05'), ('PTRATIO', '17.6'), ('MDEV', '697200.0')])
# OrderedDict([('RM', '6.826'), ('LSTAT', '4.16'), ('PTRATIO', '17.6'), ('MDEV', '695100.0')])
# OrderedDict([('RM', '6.482'), ('LSTAT', '7.19'), ('PTRATIO', '17.6'), ('MDEV', '611100.0')])
# OrderedDict([('RM', '6.812'), ('LSTAT', '4.85'), ('PTRATIO', '14.9'), ('MDEV', '737100.0')])
# OrderedDict([('RM', '7.82'), ('LSTAT', '3.76'), ('PTRATIO', '14.9'), ('MDEV', '953400.0')])
# OrderedDict([('RM', '6.968'), ('LSTAT', '4.59'), ('PTRATIO', '14.9'), ('MDEV', '743400.0')])
# OrderedDict([('RM', '7.645'), ('LSTAT', '3.01'), ('PTRATIO', '14.9'), ('MDEV', '966000.0')])
# OrderedDict([('RM', '7.088'), ('LSTAT', '7.85'), ('PTRATIO', '15.3'), ('MDEV', '676200.0')])
# OrderedDict([('RM', '6.453'), ('LSTAT', '8.23'), ('PTRATIO', '15.3'), ('MDEV', '462000.0')])
# OrderedDict([('RM', '6.23'), ('LSTAT', '12.93'), ('PTRATIO', '18.2'), ('MDEV', '422100.0')])
# OrderedDict([('RM', '6.209'), ('LSTAT', '7.14'), ('PTRATIO', '16.6'), ('MDEV', '487200.0')])
# OrderedDict([('RM', '6.315'), ('LSTAT', '7.6'), ('PTRATIO', '16.6'), ('MDEV', '468300.0')])
# OrderedDict([('RM', '6.565'), ('LSTAT', '9.51'), ('PTRATIO', '16.6'), ('MDEV', '520800.0')])
# OrderedDict([('RM', '6.861'), ('LSTAT', '3.33'), ('PTRATIO', '19.2'), ('MDEV', '598500.0')])
# OrderedDict([('RM', '7.148'), ('LSTAT', '3.56'), ('PTRATIO', '19.2'), ('MDEV', '783300.0')])
# OrderedDict([('RM', '6.63'), ('LSTAT', '4.7'), ('PTRATIO', '19.2'), ('MDEV', '585900.0')])
# OrderedDict([('RM', '6.127'), ('LSTAT', '8.58'), ('PTRATIO', '16.0'), ('MDEV', '501900.0')])
# OrderedDict([('RM', '6.009'), ('LSTAT', '10.4'), ('PTRATIO', '16.0'), ('MDEV', '455700.0')])
# OrderedDict([('RM', '6.678'), ('LSTAT', '6.27'), ('PTRATIO', '16.0'), ('MDEV', '600600.0')])
# OrderedDict([('RM', '6.549'), ('LSTAT', '7.39'), ('PTRATIO', '16.0'), ('MDEV', '569100.0')])
# OrderedDict([('RM', '5.79'), ('LSTAT', '15.84'), ('PTRATIO', '16.0'), ('MDEV', '426300.0')])
# OrderedDict([('RM', '6.345'), ('LSTAT', '4.97'), ('PTRATIO', '14.8'), ('MDEV', '472500.0')])
# OrderedDict([('RM', '7.041'), ('LSTAT', '4.74'), ('PTRATIO', '14.8'), ('MDEV', '609000.0')])
# OrderedDict([('RM', '6.871'), ('LSTAT', '6.07'), ('PTRATIO', '14.8'), ('MDEV', '520800.0')])
# OrderedDict([('RM', '6.59'), ('LSTAT', '9.5'), ('PTRATIO', '16.1'), ('MDEV', '462000.0')])
# OrderedDict([('RM', '6.495'), ('LSTAT', '8.67'), ('PTRATIO', '16.1'), ('MDEV', '554400.0')])
# OrderedDict([('RM', '6.982'), ('LSTAT', '4.86'), ('PTRATIO', '16.1'), ('MDEV', '695100.0')])
# OrderedDict([('RM', '7.236'), ('LSTAT', '6.93'), ('PTRATIO', '18.4'), ('MDEV', '758100.0')])
# OrderedDict([('RM', '6.616'), ('LSTAT', '8.93'), ('PTRATIO', '18.4'), ('MDEV', '596400.0')])
# OrderedDict([('RM', '7.42'), ('LSTAT', '6.47'), ('PTRATIO', '18.4'), ('MDEV', '701400.0')])
# OrderedDict([('RM', '6.849'), ('LSTAT', '7.53'), ('PTRATIO', '18.4'), ('MDEV', '592200.0')])
# OrderedDict([('RM', '6.635'), ('LSTAT', '4.54'), ('PTRATIO', '18.4'), ('MDEV', '478800.0')])
# OrderedDict([('RM', '5.972'), ('LSTAT', '9.97'), ('PTRATIO', '18.4'), ('MDEV', '426300.0')])
# OrderedDict([('RM', '4.973'), ('LSTAT', '12.64'), ('PTRATIO', '18.4'), ('MDEV', '338100.0')])
# OrderedDict([('RM', '6.122'), ('LSTAT', '5.98'), ('PTRATIO', '18.4'), ('MDEV', '464100.0')])
# OrderedDict([('RM', '6.023'), ('LSTAT', '11.72'), ('PTRATIO', '18.4'), ('MDEV', '407400.0')])
# OrderedDict([('RM', '6.266'), ('LSTAT', '7.9'), ('PTRATIO', '18.4'), ('MDEV', '453600.0')])
# OrderedDict([('RM', '6.567'), ('LSTAT', '9.28'), ('PTRATIO', '18.4'), ('MDEV', '499800.0')])
# OrderedDict([('RM', '5.705'), ('LSTAT', '11.5'), ('PTRATIO', '18.4'), ('MDEV', '340200.0')])
# OrderedDict([('RM', '5.914'), ('LSTAT', '18.33'), ('PTRATIO', '18.4'), ('MDEV', '373800.0')])
# OrderedDict([('RM', '5.782'), ('LSTAT', '15.94'), ('PTRATIO', '18.4'), ('MDEV', '415800.0')])
# OrderedDict([('RM', '6.382'), ('LSTAT', '10.36'), ('PTRATIO', '18.4'), ('MDEV', '485100.0')])
# OrderedDict([('RM', '6.113'), ('LSTAT', '12.73'), ('PTRATIO', '18.4'), ('MDEV', '441000.0')])
# OrderedDict([('RM', '6.426'), ('LSTAT', '7.2'), ('PTRATIO', '19.6'), ('MDEV', '499800.0')])
# OrderedDict([('RM', '6.376'), ('LSTAT', '6.87'), ('PTRATIO', '19.6'), ('MDEV', '485100.0')])
# OrderedDict([('RM', '6.041'), ('LSTAT', '7.7'), ('PTRATIO', '19.6'), ('MDEV', '428400.0')])
# OrderedDict([('RM', '5.708'), ('LSTAT', '11.74'), ('PTRATIO', '19.6'), ('MDEV', '388500.0')])
# OrderedDict([('RM', '6.415'), ('LSTAT', '6.12'), ('PTRATIO', '19.6'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '6.431'), ('LSTAT', '5.08'), ('PTRATIO', '19.6'), ('MDEV', '516600.0')])
# OrderedDict([('RM', '6.312'), ('LSTAT', '6.15'), ('PTRATIO', '19.6'), ('MDEV', '483000.0')])
# OrderedDict([('RM', '6.083'), ('LSTAT', '12.79'), ('PTRATIO', '19.6'), ('MDEV', '466200.0')])
# OrderedDict([('RM', '5.868'), ('LSTAT', '9.97'), ('PTRATIO', '16.9'), ('MDEV', '405300.0')])
# OrderedDict([('RM', '6.333'), ('LSTAT', '7.34'), ('PTRATIO', '16.9'), ('MDEV', '474600.0')])
# OrderedDict([('RM', '6.144'), ('LSTAT', '9.09'), ('PTRATIO', '16.9'), ('MDEV', '415800.0')])
# OrderedDict([('RM', '5.706'), ('LSTAT', '12.43'), ('PTRATIO', '16.9'), ('MDEV', '359100.0')])
# OrderedDict([('RM', '6.031'), ('LSTAT', '7.83'), ('PTRATIO', '16.9'), ('MDEV', '407400.0')])
# OrderedDict([('RM', '6.316'), ('LSTAT', '5.68'), ('PTRATIO', '20.2'), ('MDEV', '466200.0')])
# OrderedDict([('RM', '6.31'), ('LSTAT', '6.75'), ('PTRATIO', '20.2'), ('MDEV', '434700.0')])
# OrderedDict([('RM', '6.037'), ('LSTAT', '8.01'), ('PTRATIO', '20.2'), ('MDEV', '443100.0')])
# OrderedDict([('RM', '5.869'), ('LSTAT', '9.8'), ('PTRATIO', '20.2'), ('MDEV', '409500.0')])
# OrderedDict([('RM', '5.895'), ('LSTAT', '10.56'), ('PTRATIO', '20.2'), ('MDEV', '388500.0')])
# OrderedDict([('RM', '6.059'), ('LSTAT', '8.51'), ('PTRATIO', '20.2'), ('MDEV', '432600.0')])
# OrderedDict([('RM', '5.985'), ('LSTAT', '9.74'), ('PTRATIO', '20.2'), ('MDEV', '399000.0')])
# OrderedDict([('RM', '5.968'), ('LSTAT', '9.29'), ('PTRATIO', '20.2'), ('MDEV', '392700.0')])
# OrderedDict([('RM', '7.241'), ('LSTAT', '5.49'), ('PTRATIO', '15.5'), ('MDEV', '686700.0')])
# OrderedDict([('RM', '6.54'), ('LSTAT', '8.65'), ('PTRATIO', '15.9'), ('MDEV', '346500.0')])
# OrderedDict([('RM', '6.696'), ('LSTAT', '7.18'), ('PTRATIO', '17.6'), ('MDEV', '501900.0')])
# OrderedDict([('RM', '6.874'), ('LSTAT', '4.61'), ('PTRATIO', '17.6'), ('MDEV', '655200.0')])
# OrderedDict([('RM', '6.014'), ('LSTAT', '10.53'), ('PTRATIO', '18.8'), ('MDEV', '367500.0')])
# OrderedDict([('RM', '5.898'), ('LSTAT', '12.67'), ('PTRATIO', '18.8'), ('MDEV', '361200.0')])
# OrderedDict([('RM', '6.516'), ('LSTAT', '6.36'), ('PTRATIO', '17.9'), ('MDEV', '485100.0')])
# OrderedDict([('RM', '6.635'), ('LSTAT', '5.99'), ('PTRATIO', '17.0'), ('MDEV', '514500.0')])
# OrderedDict([('RM', '6.939'), ('LSTAT', '5.89'), ('PTRATIO', '19.7'), ('MDEV', '558600.0')])
# OrderedDict([('RM', '6.49'), ('LSTAT', '5.98'), ('PTRATIO', '19.7'), ('MDEV', '480900.0')])
# OrderedDict([('RM', '6.579'), ('LSTAT', '5.49'), ('PTRATIO', '18.3'), ('MDEV', '506100.0')])
# OrderedDict([('RM', '5.884'), ('LSTAT', '7.79'), ('PTRATIO', '18.3'), ('MDEV', '390600.0')])
# OrderedDict([('RM', '6.728'), ('LSTAT', '4.5'), ('PTRATIO', '17.0'), ('MDEV', '632100.0')])
# OrderedDict([('RM', '5.663'), ('LSTAT', '8.05'), ('PTRATIO', '22.0'), ('MDEV', '382200.0')])
# OrderedDict([('RM', '5.936'), ('LSTAT', '5.57'), ('PTRATIO', '22.0'), ('MDEV', '432600.0')])
# OrderedDict([('RM', '6.212'), ('LSTAT', '17.6'), ('PTRATIO', '20.2'), ('MDEV', '373800.0')])
# OrderedDict([('RM', '6.395'), ('LSTAT', '13.27'), ('PTRATIO', '20.2'), ('MDEV', '455700.0')])
# OrderedDict([('RM', '6.127'), ('LSTAT', '11.48'), ('PTRATIO', '20.2'), ('MDEV', '476700.0')])
# OrderedDict([('RM', '6.112'), ('LSTAT', '12.67'), ('PTRATIO', '20.2'), ('MDEV', '474600.0')])
# OrderedDict([('RM', '6.398'), ('LSTAT', '7.79'), ('PTRATIO', '20.2'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '6.251'), ('LSTAT', '14.19'), ('PTRATIO', '20.2'), ('MDEV', '417900.0')])
# OrderedDict([('RM', '5.362'), ('LSTAT', '10.19'), ('PTRATIO', '20.2'), ('MDEV', '436800.0')])
# OrderedDict([('RM', '5.803'), ('LSTAT', '14.64'), ('PTRATIO', '20.2'), ('MDEV', '352800.0')])
# OrderedDict([('RM', '3.561'), ('LSTAT', '7.12'), ('PTRATIO', '20.2'), ('MDEV', '577500.0')])
# OrderedDict([('RM', '4.963'), ('LSTAT', '14.0'), ('PTRATIO', '20.2'), ('MDEV', '459900.0')])
# OrderedDict([('RM', '3.863'), ('LSTAT', '13.33'), ('PTRATIO', '20.2'), ('MDEV', '485100.0')])
# OrderedDict([('RM', '4.906'), ('LSTAT', '34.77'), ('PTRATIO', '20.2'), ('MDEV', '289800.0')])
# OrderedDict([('RM', '4.138'), ('LSTAT', '37.97'), ('PTRATIO', '20.2'), ('MDEV', '289800.0')])
# OrderedDict([('RM', '7.313'), ('LSTAT', '13.44'), ('PTRATIO', '20.2'), ('MDEV', '315000.0')])
# OrderedDict([('RM', '6.649'), ('LSTAT', '23.24'), ('PTRATIO', '20.2'), ('MDEV', '291900.0')])
# OrderedDict([('RM', '6.794'), ('LSTAT', '21.24'), ('PTRATIO', '20.2'), ('MDEV', '279300.0')])
# OrderedDict([('RM', '6.38'), ('LSTAT', '23.69'), ('PTRATIO', '20.2'), ('MDEV', '275100.0')])
# OrderedDict([('RM', '6.223'), ('LSTAT', '21.78'), ('PTRATIO', '20.2'), ('MDEV', '214200.0')])
# OrderedDict([('RM', '6.968'), ('LSTAT', '17.21'), ('PTRATIO', '20.2'), ('MDEV', '218400.0')])
# OrderedDict([('RM', '6.545'), ('LSTAT', '21.08'), ('PTRATIO', '20.2'), ('MDEV', '228900.0')])
# OrderedDict([('RM', '5.536'), ('LSTAT', '23.6'), ('PTRATIO', '20.2'), ('MDEV', '237300.0')])
# OrderedDict([('RM', '5.52'), ('LSTAT', '24.56'), ('PTRATIO', '20.2'), ('MDEV', '258300.0')])
# OrderedDict([('RM', '4.368'), ('LSTAT', '30.63'), ('PTRATIO', '20.2'), ('MDEV', '184800.0')])
# OrderedDict([('RM', '5.277'), ('LSTAT', '30.81'), ('PTRATIO', '20.2'), ('MDEV', '151200.0')])
# OrderedDict([('RM', '4.652'), ('LSTAT', '28.28'), ('PTRATIO', '20.2'), ('MDEV', '220500.0')])
# OrderedDict([('RM', '5.0'), ('LSTAT', '31.99'), ('PTRATIO', '20.2'), ('MDEV', '155400.0')])
# OrderedDict([('RM', '4.88'), ('LSTAT', '30.62'), ('PTRATIO', '20.2'), ('MDEV', '214200.0')])
# OrderedDict([('RM', '5.39'), ('LSTAT', '20.85'), ('PTRATIO', '20.2'), ('MDEV', '241500.0')])
# OrderedDict([('RM', '5.713'), ('LSTAT', '17.11'), ('PTRATIO', '20.2'), ('MDEV', '317100.0')])
# OrderedDict([('RM', '6.051'), ('LSTAT', '18.76'), ('PTRATIO', '20.2'), ('MDEV', '487200.0')])
# OrderedDict([('RM', '5.036'), ('LSTAT', '25.68'), ('PTRATIO', '20.2'), ('MDEV', '203700.0')])
# OrderedDict([('RM', '6.193'), ('LSTAT', '15.17'), ('PTRATIO', '20.2'), ('MDEV', '289800.0')])
# OrderedDict([('RM', '5.887'), ('LSTAT', '16.35'), ('PTRATIO', '20.2'), ('MDEV', '266700.0')])
# OrderedDict([('RM', '6.471'), ('LSTAT', '17.12'), ('PTRATIO', '20.2'), ('MDEV', '275100.0')])
# OrderedDict([('RM', '6.405'), ('LSTAT', '19.37'), ('PTRATIO', '20.2'), ('MDEV', '262500.0')])
# OrderedDict([('RM', '5.747'), ('LSTAT', '19.92'), ('PTRATIO', '20.2'), ('MDEV', '178500.0')])
# OrderedDict([('RM', '5.453'), ('LSTAT', '30.59'), ('PTRATIO', '20.2'), ('MDEV', '105000.0')])
# OrderedDict([('RM', '5.852'), ('LSTAT', '29.97'), ('PTRATIO', '20.2'), ('MDEV', '132300.0')])
# OrderedDict([('RM', '5.987'), ('LSTAT', '26.77'), ('PTRATIO', '20.2'), ('MDEV', '117600.0')])
# OrderedDict([('RM', '6.343'), ('LSTAT', '20.32'), ('PTRATIO', '20.2'), ('MDEV', '151200.0')])
# OrderedDict([('RM', '6.404'), ('LSTAT', '20.31'), ('PTRATIO', '20.2'), ('MDEV', '254100.0')])
# OrderedDict([('RM', '5.349'), ('LSTAT', '19.77'), ('PTRATIO', '20.2'), ('MDEV', '174300.0')])
# OrderedDict([('RM', '5.531'), ('LSTAT', '27.38'), ('PTRATIO', '20.2'), ('MDEV', '178500.0')])
# OrderedDict([('RM', '5.683'), ('LSTAT', '22.98'), ('PTRATIO', '20.2'), ('MDEV', '105000.0')])
# OrderedDict([('RM', '4.138'), ('LSTAT', '23.34'), ('PTRATIO', '20.2'), ('MDEV', '249900.0')])
# OrderedDict([('RM', '5.608'), ('LSTAT', '12.13'), ('PTRATIO', '20.2'), ('MDEV', '585900.0')])
# OrderedDict([('RM', '5.617'), ('LSTAT', '26.4'), ('PTRATIO', '20.2'), ('MDEV', '361200.0')])
# OrderedDict([('RM', '6.852'), ('LSTAT', '19.78'), ('PTRATIO', '20.2'), ('MDEV', '577500.0')])
# OrderedDict([('RM', '5.757'), ('LSTAT', '10.11'), ('PTRATIO', '20.2'), ('MDEV', '315000.0')])
# OrderedDict([('RM', '6.657'), ('LSTAT', '21.22'), ('PTRATIO', '20.2'), ('MDEV', '361200.0')])
# OrderedDict([('RM', '4.628'), ('LSTAT', '34.37'), ('PTRATIO', '20.2'), ('MDEV', '375900.0')])
# OrderedDict([('RM', '5.155'), ('LSTAT', '20.08'), ('PTRATIO', '20.2'), ('MDEV', '342300.0')])
# OrderedDict([('RM', '4.519'), ('LSTAT', '36.98'), ('PTRATIO', '20.2'), ('MDEV', '147000.0')])
# OrderedDict([('RM', '6.434'), ('LSTAT', '29.05'), ('PTRATIO', '20.2'), ('MDEV', '151200.0')])
# OrderedDict([('RM', '6.782'), ('LSTAT', '25.79'), ('PTRATIO', '20.2'), ('MDEV', '157500.0')])
# OrderedDict([('RM', '5.304'), ('LSTAT', '26.64'), ('PTRATIO', '20.2'), ('MDEV', '218400.0')])
# OrderedDict([('RM', '5.957'), ('LSTAT', '20.62'), ('PTRATIO', '20.2'), ('MDEV', '184800.0')])
# OrderedDict([('RM', '6.824'), ('LSTAT', '22.74'), ('PTRATIO', '20.2'), ('MDEV', '176400.0')])
# OrderedDict([('RM', '6.411'), ('LSTAT', '15.02'), ('PTRATIO', '20.2'), ('MDEV', '350700.0')])
# OrderedDict([('RM', '6.006'), ('LSTAT', '15.7'), ('PTRATIO', '20.2'), ('MDEV', '298200.0')])
# OrderedDict([('RM', '5.648'), ('LSTAT', '14.1'), ('PTRATIO', '20.2'), ('MDEV', '436800.0')])
# OrderedDict([('RM', '6.103'), ('LSTAT', '23.29'), ('PTRATIO', '20.2'), ('MDEV', '281400.0')])
# OrderedDict([('RM', '5.565'), ('LSTAT', '17.16'), ('PTRATIO', '20.2'), ('MDEV', '245700.0')])
# OrderedDict([('RM', '5.896'), ('LSTAT', '24.39'), ('PTRATIO', '20.2'), ('MDEV', '174300.0')])
# OrderedDict([('RM', '5.837'), ('LSTAT', '15.69'), ('PTRATIO', '20.2'), ('MDEV', '214200.0')])
# OrderedDict([('RM', '6.202'), ('LSTAT', '14.52'), ('PTRATIO', '20.2'), ('MDEV', '228900.0')])
# OrderedDict([('RM', '6.193'), ('LSTAT', '21.52'), ('PTRATIO', '20.2'), ('MDEV', '231000.0')])
# OrderedDict([('RM', '6.38'), ('LSTAT', '24.08'), ('PTRATIO', '20.2'), ('MDEV', '199500.0')])
# OrderedDict([('RM', '6.348'), ('LSTAT', '17.64'), ('PTRATIO', '20.2'), ('MDEV', '304500.0')])
# OrderedDict([('RM', '6.833'), ('LSTAT', '19.69'), ('PTRATIO', '20.2'), ('MDEV', '296100.0')])
# OrderedDict([('RM', '6.425'), ('LSTAT', '12.03'), ('PTRATIO', '20.2'), ('MDEV', '338100.0')])
# OrderedDict([('RM', '6.436'), ('LSTAT', '16.22'), ('PTRATIO', '20.2'), ('MDEV', '300300.0')])
# OrderedDict([('RM', '6.208'), ('LSTAT', '15.17'), ('PTRATIO', '20.2'), ('MDEV', '245700.0')])
# OrderedDict([('RM', '6.629'), ('LSTAT', '23.27'), ('PTRATIO', '20.2'), ('MDEV', '281400.0')])
# OrderedDict([('RM', '6.461'), ('LSTAT', '18.05'), ('PTRATIO', '20.2'), ('MDEV', '201600.0')])
# OrderedDict([('RM', '6.152'), ('LSTAT', '26.45'), ('PTRATIO', '20.2'), ('MDEV', '182700.0')])
# OrderedDict([('RM', '5.935'), ('LSTAT', '34.02'), ('PTRATIO', '20.2'), ('MDEV', '176400.0')])
# OrderedDict([('RM', '5.627'), ('LSTAT', '22.88'), ('PTRATIO', '20.2'), ('MDEV', '268800.0')])
# OrderedDict([('RM', '5.818'), ('LSTAT', '22.11'), ('PTRATIO', '20.2'), ('MDEV', '220500.0')])
# OrderedDict([('RM', '6.406'), ('LSTAT', '19.52'), ('PTRATIO', '20.2'), ('MDEV', '359100.0')])
# OrderedDict([('RM', '6.219'), ('LSTAT', '16.59'), ('PTRATIO', '20.2'), ('MDEV', '386400.0')])
# OrderedDict([('RM', '6.485'), ('LSTAT', '18.85'), ('PTRATIO', '20.2'), ('MDEV', '323400.0')])
# OrderedDict([('RM', '5.854'), ('LSTAT', '23.79'), ('PTRATIO', '20.2'), ('MDEV', '226800.0')])
# OrderedDict([('RM', '6.459'), ('LSTAT', '23.98'), ('PTRATIO', '20.2'), ('MDEV', '247800.0')])
# OrderedDict([('RM', '6.341'), ('LSTAT', '17.79'), ('PTRATIO', '20.2'), ('MDEV', '312900.0')])
# OrderedDict([('RM', '6.251'), ('LSTAT', '16.44'), ('PTRATIO', '20.2'), ('MDEV', '264600.0')])
# OrderedDict([('RM', '6.185'), ('LSTAT', '18.13'), ('PTRATIO', '20.2'), ('MDEV', '296100.0')])
# OrderedDict([('RM', '6.417'), ('LSTAT', '19.31'), ('PTRATIO', '20.2'), ('MDEV', '273000.0')])
# OrderedDict([('RM', '6.749'), ('LSTAT', '17.44'), ('PTRATIO', '20.2'), ('MDEV', '281400.0')])
# OrderedDict([('RM', '6.655'), ('LSTAT', '17.73'), ('PTRATIO', '20.2'), ('MDEV', '319200.0')])
# OrderedDict([('RM', '6.297'), ('LSTAT', '17.27'), ('PTRATIO', '20.2'), ('MDEV', '338100.0')])
# OrderedDict([('RM', '7.393'), ('LSTAT', '16.74'), ('PTRATIO', '20.2'), ('MDEV', '373800.0')])
# OrderedDict([('RM', '6.728'), ('LSTAT', '18.71'), ('PTRATIO', '20.2'), ('MDEV', '312900.0')])
# OrderedDict([('RM', '6.525'), ('LSTAT', '18.13'), ('PTRATIO', '20.2'), ('MDEV', '296100.0')])
# OrderedDict([('RM', '5.976'), ('LSTAT', '19.01'), ('PTRATIO', '20.2'), ('MDEV', '266700.0')])
# OrderedDict([('RM', '5.936'), ('LSTAT', '16.94'), ('PTRATIO', '20.2'), ('MDEV', '283500.0')])
# OrderedDict([('RM', '6.301'), ('LSTAT', '16.23'), ('PTRATIO', '20.2'), ('MDEV', '312900.0')])
# OrderedDict([('RM', '6.081'), ('LSTAT', '14.7'), ('PTRATIO', '20.2'), ('MDEV', '420000.0')])
# OrderedDict([('RM', '6.701'), ('LSTAT', '16.42'), ('PTRATIO', '20.2'), ('MDEV', '344400.0')])
# OrderedDict([('RM', '6.376'), ('LSTAT', '14.65'), ('PTRATIO', '20.2'), ('MDEV', '371700.0')])
# OrderedDict([('RM', '6.317'), ('LSTAT', '13.99'), ('PTRATIO', '20.2'), ('MDEV', '409500.0')])
# OrderedDict([('RM', '6.513'), ('LSTAT', '10.29'), ('PTRATIO', '20.2'), ('MDEV', '424200.0')])
# OrderedDict([('RM', '6.209'), ('LSTAT', '13.22'), ('PTRATIO', '20.2'), ('MDEV', '449400.0')])
# OrderedDict([('RM', '5.759'), ('LSTAT', '14.13'), ('PTRATIO', '20.2'), ('MDEV', '417900.0')])
# OrderedDict([('RM', '5.952'), ('LSTAT', '17.15'), ('PTRATIO', '20.2'), ('MDEV', '399000.0')])
# OrderedDict([('RM', '6.003'), ('LSTAT', '21.32'), ('PTRATIO', '20.2'), ('MDEV', '401100.0')])
# OrderedDict([('RM', '5.926'), ('LSTAT', '18.13'), ('PTRATIO', '20.2'), ('MDEV', '401100.0')])
# OrderedDict([('RM', '5.713'), ('LSTAT', '14.76'), ('PTRATIO', '20.2'), ('MDEV', '422100.0')])
# OrderedDict([('RM', '6.167'), ('LSTAT', '16.29'), ('PTRATIO', '20.2'), ('MDEV', '417900.0')])
# OrderedDict([('RM', '6.229'), ('LSTAT', '12.87'), ('PTRATIO', '20.2'), ('MDEV', '411600.0')])
# OrderedDict([('RM', '6.437'), ('LSTAT', '14.36'), ('PTRATIO', '20.2'), ('MDEV', '487200.0')])
# OrderedDict([('RM', '6.98'), ('LSTAT', '11.66'), ('PTRATIO', '20.2'), ('MDEV', '625800.0')])
# OrderedDict([('RM', '5.427'), ('LSTAT', '18.14'), ('PTRATIO', '20.2'), ('MDEV', '289800.0')])
# OrderedDict([('RM', '6.162'), ('LSTAT', '24.1'), ('PTRATIO', '20.2'), ('MDEV', '279300.0')])
# OrderedDict([('RM', '6.484'), ('LSTAT', '18.68'), ('PTRATIO', '20.2'), ('MDEV', '350700.0')])
# OrderedDict([('RM', '5.304'), ('LSTAT', '24.91'), ('PTRATIO', '20.2'), ('MDEV', '252000.0')])
# OrderedDict([('RM', '6.185'), ('LSTAT', '18.03'), ('PTRATIO', '20.2'), ('MDEV', '306600.0')])
# OrderedDict([('RM', '6.229'), ('LSTAT', '13.11'), ('PTRATIO', '20.2'), ('MDEV', '449400.0')])
# OrderedDict([('RM', '6.242'), ('LSTAT', '10.74'), ('PTRATIO', '20.2'), ('MDEV', '483000.0')])
# OrderedDict([('RM', '6.75'), ('LSTAT', '7.74'), ('PTRATIO', '20.2'), ('MDEV', '497700.0')])
# OrderedDict([('RM', '7.061'), ('LSTAT', '7.01'), ('PTRATIO', '20.2'), ('MDEV', '525000.0')])
# OrderedDict([('RM', '5.762'), ('LSTAT', '10.42'), ('PTRATIO', '20.2'), ('MDEV', '457800.0')])
# OrderedDict([('RM', '5.871'), ('LSTAT', '13.34'), ('PTRATIO', '20.2'), ('MDEV', '432600.0')])
# OrderedDict([('RM', '6.312'), ('LSTAT', '10.58'), ('PTRATIO', '20.2'), ('MDEV', '445200.0')])
# OrderedDict([('RM', '6.114'), ('LSTAT', '14.98'), ('PTRATIO', '20.2'), ('MDEV', '401100.0')])
# OrderedDict([('RM', '5.905'), ('LSTAT', '11.45'), ('PTRATIO', '20.2'), ('MDEV', '432600.0')])
# OrderedDict([('RM', '5.454'), ('LSTAT', '18.06'), ('PTRATIO', '20.1'), ('MDEV', '319200.0')])
# OrderedDict([('RM', '5.414'), ('LSTAT', '23.97'), ('PTRATIO', '20.1'), ('MDEV', '147000.0')])
# OrderedDict([('RM', '5.093'), ('LSTAT', '29.68'), ('PTRATIO', '20.1'), ('MDEV', '170100.0')])
# OrderedDict([('RM', '5.983'), ('LSTAT', '18.07'), ('PTRATIO', '20.1'), ('MDEV', '285600.0')])
# OrderedDict([('RM', '5.983'), ('LSTAT', '13.35'), ('PTRATIO', '20.1'), ('MDEV', '422100.0')])
# OrderedDict([('RM', '5.707'), ('LSTAT', '12.01'), ('PTRATIO', '19.2'), ('MDEV', '457800.0')])
# OrderedDict([('RM', '5.926'), ('LSTAT', '13.59'), ('PTRATIO', '19.2'), ('MDEV', '514500.0')])
# OrderedDict([('RM', '5.67'), ('LSTAT', '17.6'), ('PTRATIO', '19.2'), ('MDEV', '485100.0')])
# OrderedDict([('RM', '5.39'), ('LSTAT', '21.14'), ('PTRATIO', '19.2'), ('MDEV', '413700.0')])
# OrderedDict([('RM', '5.794'), ('LSTAT', '14.1'), ('PTRATIO', '19.2'), ('MDEV', '384300.0')])
# OrderedDict([('RM', '6.019'), ('LSTAT', '12.92'), ('PTRATIO', '19.2'), ('MDEV', '445200.0')])
# OrderedDict([('RM', '5.569'), ('LSTAT', '15.1'), ('PTRATIO', '19.2'), ('MDEV', '367500.0')])
# OrderedDict([('RM', '6.027'), ('LSTAT', '14.33'), ('PTRATIO', '19.2'), ('MDEV', '352800.0')])
# OrderedDict([('RM', '6.593'), ('LSTAT', '9.67'), ('PTRATIO', '21.0'), ('MDEV', '470400.0')])
# OrderedDict([('RM', '6.12'), ('LSTAT', '9.08'), ('PTRATIO', '21.0'), ('MDEV', '432600.0')])
# OrderedDict([('RM', '6.976'), ('LSTAT', '5.64'), ('PTRATIO', '21.0'), ('MDEV', '501900.0')])
# OrderedDict([('RM', '6.794'), ('LSTAT', '6.48'), ('PTRATIO', '21.0'), ('MDEV', '462000.0')])
# OrderedDict([('RM', '6.03'), ('LSTAT', '7.88'), ('PTRATIO', '21.0'), ('MDEV', '249900.0')])

# %%
rows[0]['RM']
# Out:
# '6.575'

# %% [markdown]
# # Reading JSON
# * `import json`
# * `json.load()` or `json.loads()`
#
# #  Writing JSON
# * `json.dump()` or `json.dumps()`

# %%
records = [row for row in csv.DictReader(StringIO(response.text))]

import json
json.dump(records, open('./boston.json', 'w'))
json.load(open('./boston.json', 'r'))

serialized = json.dumps(records)
serialized

deserialized = json.loads(serialized)
deserialized
# Out:
# [{'LSTAT': '4.98', 'MDEV': '504000.0', 'PTRATIO': '15.3', 'RM': '6.575'},
#  {'LSTAT': '9.14', 'MDEV': '453600.0', 'PTRATIO': '17.8', 'RM': '6.421'},
#  {'LSTAT': '4.03', 'MDEV': '728700.0', 'PTRATIO': '17.8', 'RM': '7.185'},
#  {'LSTAT': '2.94', 'MDEV': '701400.0', 'PTRATIO': '18.7', 'RM': '6.998'},
#  {'LSTAT': '5.33', 'MDEV': '760200.0', 'PTRATIO': '18.7', 'RM': '7.147'},
#  {'LSTAT': '5.21', 'MDEV': '602700.0', 'PTRATIO': '18.7', 'RM': '6.43'},
#  {'LSTAT': '12.43', 'MDEV': '480900.0', 'PTRATIO': '15.2', 'RM': '6.012'},
#  {'LSTAT': '19.15', 'MDEV': '569100.0', 'PTRATIO': '15.2', 'RM': '6.172'},
#  {'LSTAT': '29.93', 'MDEV': '346500.0', 'PTRATIO': '15.2', 'RM': '5.631'},
#  {'LSTAT': '17.1', 'MDEV': '396900.0', 'PTRATIO': '15.2', 'RM': '6.004'},
#  {'LSTAT': '20.45', 'MDEV': '315000.0', 'PTRATIO': '15.2', 'RM': '6.377'},
#  {'LSTAT': '13.27', 'MDEV': '396900.0', 'PTRATIO': '15.2', 'RM': '6.009'},
#  {'LSTAT': '15.71', 'MDEV': '455700.0', 'PTRATIO': '15.2', 'RM': '5.889'},
#  {'LSTAT': '8.26', 'MDEV': '428400.0', 'PTRATIO': '21.0', 'RM': '5.949'},
#  {'LSTAT': '10.26', 'MDEV': '382200.0', 'PTRATIO': '21.0', 'RM': '6.096'},
#  {'LSTAT': '8.47', 'MDEV': '417900.0', 'PTRATIO': '21.0', 'RM': '5.834'},
#  {'LSTAT': '6.58', 'MDEV': '485100.0', 'PTRATIO': '21.0', 'RM': '5.935'},
#  {'LSTAT': '14.67', 'MDEV': '367500.0', 'PTRATIO': '21.0', 'RM': '5.99'},
#  {'LSTAT': '11.69', 'MDEV': '424200.0', 'PTRATIO': '21.0', 'RM': '5.456'},
#  {'LSTAT': '11.28', 'MDEV': '382200.0', 'PTRATIO': '21.0', 'RM': '5.727'},
#  {'LSTAT': '21.02', 'MDEV': '285600.0', 'PTRATIO': '21.0', 'RM': '5.57'},
#  {'LSTAT': '13.83', 'MDEV': '411600.0', 'PTRATIO': '21.0', 'RM': '5.965'},
#  {'LSTAT': '18.72', 'MDEV': '319200.0', 'PTRATIO': '21.0', 'RM': '6.142'},
#  {'LSTAT': '19.88', 'MDEV': '304500.0', 'PTRATIO': '21.0', 'RM': '5.813'},
#  {'LSTAT': '16.3', 'MDEV': '327600.0', 'PTRATIO': '21.0', 'RM': '5.924'},
#  {'LSTAT': '16.51', 'MDEV': '291900.0', 'PTRATIO': '21.0', 'RM': '5.599'},
#  {'LSTAT': '14.81', 'MDEV': '348600.0', 'PTRATIO': '21.0', 'RM': '5.813'},
#  {'LSTAT': '17.28', 'MDEV': '310800.0', 'PTRATIO': '21.0', 'RM': '6.047'},
#  {'LSTAT': '12.8', 'MDEV': '386400.0', 'PTRATIO': '21.0', 'RM': '6.495'},
#  {'LSTAT': '11.98', 'MDEV': '441000.0', 'PTRATIO': '21.0', 'RM': '6.674'},
#  {'LSTAT': '22.6', 'MDEV': '266700.0', 'PTRATIO': '21.0', 'RM': '5.713'},
#  {'LSTAT': '13.04', 'MDEV': '304500.0', 'PTRATIO': '21.0', 'RM': '6.072'},
#  {'LSTAT': '27.71', 'MDEV': '277200.0', 'PTRATIO': '21.0', 'RM': '5.95'},
#  {'LSTAT': '18.35', 'MDEV': '275100.0', 'PTRATIO': '21.0', 'RM': '5.701'},
#  {'LSTAT': '20.34', 'MDEV': '283500.0', 'PTRATIO': '21.0', 'RM': '6.096'},
#  {'LSTAT': '9.68', 'MDEV': '396900.0', 'PTRATIO': '19.2', 'RM': '5.933'},
#  {'LSTAT': '11.41', 'MDEV': '420000.0', 'PTRATIO': '19.2', 'RM': '5.841'},
#  {'LSTAT': '8.77', 'MDEV': '441000.0', 'PTRATIO': '19.2', 'RM': '5.85'},
#  {'LSTAT': '10.13', 'MDEV': '518700.0', 'PTRATIO': '19.2', 'RM': '5.966'},
#  {'LSTAT': '4.32', 'MDEV': '646800.0', 'PTRATIO': '18.3', 'RM': '6.595'},
#  {'LSTAT': '1.98', 'MDEV': '732900.0', 'PTRATIO': '18.3', 'RM': '7.024'},
#  {'LSTAT': '4.84', 'MDEV': '558600.0', 'PTRATIO': '17.9', 'RM': '6.77'},
#  {'LSTAT': '5.81', 'MDEV': '531300.0', 'PTRATIO': '17.9', 'RM': '6.169'},
#  {'LSTAT': '7.44', 'MDEV': '518700.0', 'PTRATIO': '17.9', 'RM': '6.211'},
#  {'LSTAT': '9.55', 'MDEV': '445200.0', 'PTRATIO': '17.9', 'RM': '6.069'},
#  {'LSTAT': '10.21', 'MDEV': '405300.0', 'PTRATIO': '17.9', 'RM': '5.682'},
#  {'LSTAT': '14.15', 'MDEV': '420000.0', 'PTRATIO': '17.9', 'RM': '5.786'},
#  {'LSTAT': '18.8', 'MDEV': '348600.0', 'PTRATIO': '17.9', 'RM': '6.03'},
#  {'LSTAT': '30.81', 'MDEV': '302400.0', 'PTRATIO': '17.9', 'RM': '5.399'},
#  {'LSTAT': '16.2', 'MDEV': '407400.0', 'PTRATIO': '17.9', 'RM': '5.602'},
#  {'LSTAT': '13.45', 'MDEV': '413700.0', 'PTRATIO': '16.8', 'RM': '5.963'},
#  {'LSTAT': '9.43', 'MDEV': '430500.0', 'PTRATIO': '16.8', 'RM': '6.115'},
#  {'LSTAT': '5.28', 'MDEV': '525000.0', 'PTRATIO': '16.8', 'RM': '6.511'},
#  {'LSTAT': '8.43', 'MDEV': '491400.0', 'PTRATIO': '16.8', 'RM': '5.998'},
#  {'LSTAT': '14.8', 'MDEV': '396900.0', 'PTRATIO': '21.1', 'RM': '5.888'},
#  {'LSTAT': '4.81', 'MDEV': '743400.0', 'PTRATIO': '17.9', 'RM': '7.249'},
#  {'LSTAT': '5.77', 'MDEV': '518700.0', 'PTRATIO': '17.3', 'RM': '6.383'},
#  {'LSTAT': '3.95', 'MDEV': '663600.0', 'PTRATIO': '15.1', 'RM': '6.816'},
#  {'LSTAT': '6.86', 'MDEV': '489300.0', 'PTRATIO': '19.7', 'RM': '6.145'},
#  {'LSTAT': '9.22', 'MDEV': '411600.0', 'PTRATIO': '19.7', 'RM': '5.927'},
#  {'LSTAT': '13.15', 'MDEV': '392700.0', 'PTRATIO': '19.7', 'RM': '5.741'},
#  {'LSTAT': '14.44', 'MDEV': '336000.0', 'PTRATIO': '19.7', 'RM': '5.966'},
#  {'LSTAT': '6.73', 'MDEV': '466200.0', 'PTRATIO': '19.7', 'RM': '6.456'},
#  {'LSTAT': '9.5', 'MDEV': '525000.0', 'PTRATIO': '19.7', 'RM': '6.762'},
#  {'LSTAT': '8.05', 'MDEV': '693000.0', 'PTRATIO': '18.6', 'RM': '7.104'},
#  {'LSTAT': '4.67', 'MDEV': '493500.0', 'PTRATIO': '16.1', 'RM': '6.29'},
#  {'LSTAT': '10.24', 'MDEV': '407400.0', 'PTRATIO': '16.1', 'RM': '5.787'},
#  {'LSTAT': '8.1', 'MDEV': '462000.0', 'PTRATIO': '18.9', 'RM': '5.878'},
#  {'LSTAT': '13.09', 'MDEV': '365400.0', 'PTRATIO': '18.9', 'RM': '5.594'},
#  {'LSTAT': '8.79', 'MDEV': '438900.0', 'PTRATIO': '18.9', 'RM': '5.885'},
#  {'LSTAT': '6.72', 'MDEV': '508200.0', 'PTRATIO': '19.2', 'RM': '6.417'},
#  {'LSTAT': '9.88', 'MDEV': '455700.0', 'PTRATIO': '19.2', 'RM': '5.961'},
#  {'LSTAT': '5.52', 'MDEV': '478800.0', 'PTRATIO': '19.2', 'RM': '6.065'},
#  {'LSTAT': '7.54', 'MDEV': '491400.0', 'PTRATIO': '19.2', 'RM': '6.245'},
#  {'LSTAT': '6.78', 'MDEV': '506100.0', 'PTRATIO': '18.7', 'RM': '6.273'},
#  {'LSTAT': '8.94', 'MDEV': '449400.0', 'PTRATIO': '18.7', 'RM': '6.286'},
#  {'LSTAT': '11.97', 'MDEV': '420000.0', 'PTRATIO': '18.7', 'RM': '6.279'},
#  {'LSTAT': '10.27', 'MDEV': '436800.0', 'PTRATIO': '18.7', 'RM': '6.14'},
#  {'LSTAT': '12.34', 'MDEV': '445200.0', 'PTRATIO': '18.7', 'RM': '6.232'},
#  {'LSTAT': '9.1', 'MDEV': '426300.0', 'PTRATIO': '18.7', 'RM': '5.874'},
#  {'LSTAT': '5.29', 'MDEV': '588000.0', 'PTRATIO': '19.0', 'RM': '6.727'},
#  {'LSTAT': '7.22', 'MDEV': '501900.0', 'PTRATIO': '19.0', 'RM': '6.619'},
#  {'LSTAT': '6.72', 'MDEV': '520800.0', 'PTRATIO': '19.0', 'RM': '6.302'},
#  {'LSTAT': '7.51', 'MDEV': '480900.0', 'PTRATIO': '19.0', 'RM': '6.167'},
#  {'LSTAT': '9.62', 'MDEV': '501900.0', 'PTRATIO': '18.5', 'RM': '6.389'},
#  {'LSTAT': '6.53', 'MDEV': '558600.0', 'PTRATIO': '18.5', 'RM': '6.63'},
#  {'LSTAT': '12.86', 'MDEV': '472500.0', 'PTRATIO': '18.5', 'RM': '6.015'},
#  {'LSTAT': '8.44', 'MDEV': '466200.0', 'PTRATIO': '18.5', 'RM': '6.121'},
#  {'LSTAT': '5.5', 'MDEV': '495600.0', 'PTRATIO': '17.8', 'RM': '7.007'},
#  {'LSTAT': '5.7', 'MDEV': '602700.0', 'PTRATIO': '17.8', 'RM': '7.079'},
#  {'LSTAT': '8.81', 'MDEV': '474600.0', 'PTRATIO': '17.8', 'RM': '6.417'},
#  {'LSTAT': '8.2', 'MDEV': '462000.0', 'PTRATIO': '17.8', 'RM': '6.405'},
#  {'LSTAT': '8.16', 'MDEV': '480900.0', 'PTRATIO': '18.2', 'RM': '6.442'},
#  {'LSTAT': '6.21', 'MDEV': '525000.0', 'PTRATIO': '18.2', 'RM': '6.211'},
#  {'LSTAT': '10.59', 'MDEV': '432600.0', 'PTRATIO': '18.2', 'RM': '6.249'},
#  {'LSTAT': '6.65', 'MDEV': '596400.0', 'PTRATIO': '18.0', 'RM': '6.625'},
#  {'LSTAT': '11.34', 'MDEV': '449400.0', 'PTRATIO': '18.0', 'RM': '6.163'},
#  {'LSTAT': '4.21', 'MDEV': '812700.0', 'PTRATIO': '18.0', 'RM': '8.069'},
#  {'LSTAT': '3.57', 'MDEV': '919800.0', 'PTRATIO': '18.0', 'RM': '7.82'},
#  {'LSTAT': '6.19', 'MDEV': '697200.0', 'PTRATIO': '18.0', 'RM': '7.416'},
#  {'LSTAT': '9.42', 'MDEV': '577500.0', 'PTRATIO': '20.9', 'RM': '6.727'},
#  {'LSTAT': '7.67', 'MDEV': '556500.0', 'PTRATIO': '20.9', 'RM': '6.781'},
#  {'LSTAT': '10.63', 'MDEV': '390600.0', 'PTRATIO': '20.9', 'RM': '6.405'},
#  {'LSTAT': '13.44', 'MDEV': '405300.0', 'PTRATIO': '20.9', 'RM': '6.137'},
#  {'LSTAT': '12.33', 'MDEV': '422100.0', 'PTRATIO': '20.9', 'RM': '6.167'},
#  {'LSTAT': '16.47', 'MDEV': '409500.0', 'PTRATIO': '20.9', 'RM': '5.851'},
#  {'LSTAT': '18.66', 'MDEV': '409500.0', 'PTRATIO': '20.9', 'RM': '5.836'},
#  {'LSTAT': '14.09', 'MDEV': '428400.0', 'PTRATIO': '20.9', 'RM': '6.127'},
#  {'LSTAT': '12.27', 'MDEV': '415800.0', 'PTRATIO': '20.9', 'RM': '6.474'},
#  {'LSTAT': '15.55', 'MDEV': '407400.0', 'PTRATIO': '20.9', 'RM': '6.229'},
#  {'LSTAT': '13.0', 'MDEV': '455700.0', 'PTRATIO': '20.9', 'RM': '6.195'},
#  {'LSTAT': '10.16', 'MDEV': '478800.0', 'PTRATIO': '17.8', 'RM': '6.715'},
#  {'LSTAT': '16.21', 'MDEV': '394800.0', 'PTRATIO': '17.8', 'RM': '5.913'},
#  {'LSTAT': '17.09', 'MDEV': '392700.0', 'PTRATIO': '17.8', 'RM': '6.092'},
#  {'LSTAT': '10.45', 'MDEV': '388500.0', 'PTRATIO': '17.8', 'RM': '6.254'},
#  {'LSTAT': '15.76', 'MDEV': '384300.0', 'PTRATIO': '17.8', 'RM': '5.928'},
#  {'LSTAT': '12.04', 'MDEV': '445200.0', 'PTRATIO': '17.8', 'RM': '6.176'},
#  {'LSTAT': '10.3', 'MDEV': '403200.0', 'PTRATIO': '17.8', 'RM': '6.021'},
#  {'LSTAT': '15.37', 'MDEV': '428400.0', 'PTRATIO': '17.8', 'RM': '5.872'},
#  {'LSTAT': '13.61', 'MDEV': '405300.0', 'PTRATIO': '17.8', 'RM': '5.731'},
#  {'LSTAT': '14.37', 'MDEV': '462000.0', 'PTRATIO': '19.1', 'RM': '5.87'},
#  {'LSTAT': '14.27', 'MDEV': '426300.0', 'PTRATIO': '19.1', 'RM': '6.004'},
#  {'LSTAT': '17.93', 'MDEV': '430500.0', 'PTRATIO': '19.1', 'RM': '5.961'},
#  {'LSTAT': '25.41', 'MDEV': '363300.0', 'PTRATIO': '19.1', 'RM': '5.856'},
#  {'LSTAT': '17.58', 'MDEV': '394800.0', 'PTRATIO': '19.1', 'RM': '5.879'},
#  {'LSTAT': '14.81', 'MDEV': '449400.0', 'PTRATIO': '19.1', 'RM': '5.986'},
#  {'LSTAT': '27.26', 'MDEV': '329700.0', 'PTRATIO': '19.1', 'RM': '5.613'},
#  {'LSTAT': '17.19', 'MDEV': '340200.0', 'PTRATIO': '21.2', 'RM': '5.693'},
#  {'LSTAT': '15.39', 'MDEV': '378000.0', 'PTRATIO': '21.2', 'RM': '6.431'},
#  {'LSTAT': '18.34', 'MDEV': '300300.0', 'PTRATIO': '21.2', 'RM': '5.637'},
#  {'LSTAT': '12.6', 'MDEV': '403200.0', 'PTRATIO': '21.2', 'RM': '6.458'},
#  {'LSTAT': '12.26', 'MDEV': '411600.0', 'PTRATIO': '21.2', 'RM': '6.326'},
#  {'LSTAT': '11.12', 'MDEV': '483000.0', 'PTRATIO': '21.2', 'RM': '6.372'},
#  {'LSTAT': '15.03', 'MDEV': '386400.0', 'PTRATIO': '21.2', 'RM': '5.822'},
#  {'LSTAT': '17.31', 'MDEV': '327600.0', 'PTRATIO': '21.2', 'RM': '5.757'},
#  {'LSTAT': '16.96', 'MDEV': '380100.0', 'PTRATIO': '21.2', 'RM': '6.335'},
#  {'LSTAT': '16.9', 'MDEV': '365400.0', 'PTRATIO': '21.2', 'RM': '5.942'},
#  {'LSTAT': '14.59', 'MDEV': '359100.0', 'PTRATIO': '21.2', 'RM': '6.454'},
#  {'LSTAT': '21.32', 'MDEV': '279300.0', 'PTRATIO': '21.2', 'RM': '5.857'},
#  {'LSTAT': '18.46', 'MDEV': '373800.0', 'PTRATIO': '21.2', 'RM': '6.151'},
#  {'LSTAT': '24.16', 'MDEV': '294000.0', 'PTRATIO': '21.2', 'RM': '6.174'},
#  {'LSTAT': '34.41', 'MDEV': '302400.0', 'PTRATIO': '21.2', 'RM': '5.019'},
#  {'LSTAT': '26.82', 'MDEV': '281400.0', 'PTRATIO': '14.7', 'RM': '5.403'},
#  {'LSTAT': '26.42', 'MDEV': '327600.0', 'PTRATIO': '14.7', 'RM': '5.468'},
#  {'LSTAT': '29.29', 'MDEV': '247800.0', 'PTRATIO': '14.7', 'RM': '4.903'},
#  {'LSTAT': '27.8', 'MDEV': '289800.0', 'PTRATIO': '14.7', 'RM': '6.13'},
#  {'LSTAT': '16.65', 'MDEV': '327600.0', 'PTRATIO': '14.7', 'RM': '5.628'},
#  {'LSTAT': '29.53', 'MDEV': '306600.0', 'PTRATIO': '14.7', 'RM': '4.926'},
#  {'LSTAT': '28.32', 'MDEV': '373800.0', 'PTRATIO': '14.7', 'RM': '5.186'},
#  {'LSTAT': '21.45', 'MDEV': '323400.0', 'PTRATIO': '14.7', 'RM': '5.597'},
#  {'LSTAT': '14.1', 'MDEV': '451500.0', 'PTRATIO': '14.7', 'RM': '6.122'},
#  {'LSTAT': '13.28', 'MDEV': '411600.0', 'PTRATIO': '14.7', 'RM': '5.404'},
#  {'LSTAT': '12.12', 'MDEV': '321300.0', 'PTRATIO': '14.7', 'RM': '5.012'},
#  {'LSTAT': '15.79', 'MDEV': '407400.0', 'PTRATIO': '14.7', 'RM': '5.709'},
#  {'LSTAT': '15.12', 'MDEV': '357000.0', 'PTRATIO': '14.7', 'RM': '6.129'},
#  {'LSTAT': '15.02', 'MDEV': '327600.0', 'PTRATIO': '14.7', 'RM': '6.152'},
#  {'LSTAT': '16.14', 'MDEV': '275100.0', 'PTRATIO': '14.7', 'RM': '5.272'},
#  {'LSTAT': '4.59', 'MDEV': '867300.0', 'PTRATIO': '14.7', 'RM': '6.943'},
#  {'LSTAT': '6.43', 'MDEV': '510300.0', 'PTRATIO': '14.7', 'RM': '6.066'},
#  {'LSTAT': '7.39', 'MDEV': '489300.0', 'PTRATIO': '14.7', 'RM': '6.51'},
#  {'LSTAT': '5.5', 'MDEV': '567000.0', 'PTRATIO': '14.7', 'RM': '6.25'},
#  {'LSTAT': '11.64', 'MDEV': '476700.0', 'PTRATIO': '14.7', 'RM': '5.854'},
#  {'LSTAT': '9.81', 'MDEV': '525000.0', 'PTRATIO': '14.7', 'RM': '6.101'},
#  {'LSTAT': '12.14', 'MDEV': '499800.0', 'PTRATIO': '14.7', 'RM': '5.877'},
#  {'LSTAT': '11.1', 'MDEV': '499800.0', 'PTRATIO': '14.7', 'RM': '6.319'},
#  {'LSTAT': '11.32', 'MDEV': '468300.0', 'PTRATIO': '14.7', 'RM': '6.402'},
#  {'LSTAT': '14.43', 'MDEV': '365400.0', 'PTRATIO': '14.7', 'RM': '5.875'},
#  {'LSTAT': '12.03', 'MDEV': '401100.0', 'PTRATIO': '14.7', 'RM': '5.88'},
#  {'LSTAT': '14.69', 'MDEV': '485100.0', 'PTRATIO': '16.6', 'RM': '5.572'},
#  {'LSTAT': '9.04', 'MDEV': '495600.0', 'PTRATIO': '16.6', 'RM': '6.416'},
#  {'LSTAT': '9.64', 'MDEV': '474600.0', 'PTRATIO': '16.6', 'RM': '5.859'},
#  {'LSTAT': '5.33', 'MDEV': '617400.0', 'PTRATIO': '16.6', 'RM': '6.546'},
#  {'LSTAT': '10.11', 'MDEV': '487200.0', 'PTRATIO': '16.6', 'RM': '6.02'},
#  {'LSTAT': '6.29', 'MDEV': '516600.0', 'PTRATIO': '16.6', 'RM': '6.315'},
#  {'LSTAT': '6.92', 'MDEV': '627900.0', 'PTRATIO': '16.6', 'RM': '6.86'},
#  {'LSTAT': '5.04', 'MDEV': '781200.0', 'PTRATIO': '17.8', 'RM': '6.98'},
#  {'LSTAT': '7.56', 'MDEV': '835800.0', 'PTRATIO': '17.8', 'RM': '7.765'},
#  {'LSTAT': '9.45', 'MDEV': '760200.0', 'PTRATIO': '17.8', 'RM': '6.144'},
#  {'LSTAT': '4.82', 'MDEV': '795900.0', 'PTRATIO': '17.8', 'RM': '7.155'},
#  {'LSTAT': '5.68', 'MDEV': '682500.0', 'PTRATIO': '17.8', 'RM': '6.563'},
#  {'LSTAT': '13.98', 'MDEV': '554400.0', 'PTRATIO': '17.8', 'RM': '5.604'},
#  {'LSTAT': '13.15', 'MDEV': '621600.0', 'PTRATIO': '17.8', 'RM': '6.153'},
#  {'LSTAT': '6.68', 'MDEV': '672000.0', 'PTRATIO': '15.2', 'RM': '6.782'},
#  {'LSTAT': '4.56', 'MDEV': '625800.0', 'PTRATIO': '15.2', 'RM': '6.556'},
#  {'LSTAT': '5.39', 'MDEV': '732900.0', 'PTRATIO': '15.2', 'RM': '7.185'},
#  {'LSTAT': '5.1', 'MDEV': '777000.0', 'PTRATIO': '15.2', 'RM': '6.951'},
#  {'LSTAT': '4.69', 'MDEV': '640500.0', 'PTRATIO': '15.2', 'RM': '6.739'},
#  {'LSTAT': '2.87', 'MDEV': '764400.0', 'PTRATIO': '15.2', 'RM': '7.178'},
#  {'LSTAT': '5.03', 'MDEV': '653100.0', 'PTRATIO': '15.6', 'RM': '6.8'},
#  {'LSTAT': '4.38', 'MDEV': '611100.0', 'PTRATIO': '15.6', 'RM': '6.604'},
#  {'LSTAT': '4.08', 'MDEV': '699300.0', 'PTRATIO': '12.6', 'RM': '7.287'},
#  {'LSTAT': '8.61', 'MDEV': '636300.0', 'PTRATIO': '12.6', 'RM': '7.107'},
#  {'LSTAT': '6.62', 'MDEV': '726600.0', 'PTRATIO': '12.6', 'RM': '7.274'},
#  {'LSTAT': '4.56', 'MDEV': '732900.0', 'PTRATIO': '17.0', 'RM': '6.975'},
#  {'LSTAT': '4.45', 'MDEV': '690900.0', 'PTRATIO': '17.0', 'RM': '7.135'},
#  {'LSTAT': '7.43', 'MDEV': '506100.0', 'PTRATIO': '14.7', 'RM': '6.162'},
#  {'LSTAT': '3.11', 'MDEV': '888300.0', 'PTRATIO': '14.7', 'RM': '7.61'},
#  {'LSTAT': '3.81', 'MDEV': '1018500.0', 'PTRATIO': '14.7', 'RM': '7.853'},
#  {'LSTAT': '10.87', 'MDEV': '474600.0', 'PTRATIO': '18.6', 'RM': '5.891'},
#  {'LSTAT': '10.97', 'MDEV': '512400.0', 'PTRATIO': '18.6', 'RM': '6.326'},
#  {'LSTAT': '18.06', 'MDEV': '472500.0', 'PTRATIO': '18.6', 'RM': '5.783'},
#  {'LSTAT': '14.66', 'MDEV': '512400.0', 'PTRATIO': '18.6', 'RM': '6.064'},
#  {'LSTAT': '23.09', 'MDEV': '420000.0', 'PTRATIO': '18.6', 'RM': '5.344'},
#  {'LSTAT': '17.27', 'MDEV': '455700.0', 'PTRATIO': '18.6', 'RM': '5.96'},
#  {'LSTAT': '23.98', 'MDEV': '405300.0', 'PTRATIO': '18.6', 'RM': '5.404'},
#  {'LSTAT': '16.03', 'MDEV': '470400.0', 'PTRATIO': '18.6', 'RM': '5.807'},
#  {'LSTAT': '9.38', 'MDEV': '590100.0', 'PTRATIO': '18.6', 'RM': '6.375'},
#  {'LSTAT': '29.55', 'MDEV': '497700.0', 'PTRATIO': '18.6', 'RM': '5.412'},
#  {'LSTAT': '9.47', 'MDEV': '525000.0', 'PTRATIO': '18.6', 'RM': '6.182'},
#  {'LSTAT': '13.51', 'MDEV': '489300.0', 'PTRATIO': '16.4', 'RM': '5.888'},
#  {'LSTAT': '9.69', 'MDEV': '602700.0', 'PTRATIO': '16.4', 'RM': '6.642'},
#  {'LSTAT': '17.92', 'MDEV': '451500.0', 'PTRATIO': '16.4', 'RM': '5.951'},
#  {'LSTAT': '10.5', 'MDEV': '483000.0', 'PTRATIO': '16.4', 'RM': '6.373'},
#  {'LSTAT': '9.71', 'MDEV': '560700.0', 'PTRATIO': '17.4', 'RM': '6.951'},
#  {'LSTAT': '21.46', 'MDEV': '455700.0', 'PTRATIO': '17.4', 'RM': '6.164'},
#  {'LSTAT': '9.93', 'MDEV': '577500.0', 'PTRATIO': '17.4', 'RM': '6.879'},
#  {'LSTAT': '7.6', 'MDEV': '632100.0', 'PTRATIO': '17.4', 'RM': '6.618'},
#  {'LSTAT': '4.14', 'MDEV': '940800.0', 'PTRATIO': '17.4', 'RM': '8.266'},
#  {'LSTAT': '3.13', 'MDEV': '789600.0', 'PTRATIO': '17.4', 'RM': '8.04'},
#  {'LSTAT': '6.36', 'MDEV': '663600.0', 'PTRATIO': '17.4', 'RM': '7.163'},
#  {'LSTAT': '3.92', 'MDEV': '980700.0', 'PTRATIO': '17.4', 'RM': '7.686'},
#  {'LSTAT': '3.76', 'MDEV': '661500.0', 'PTRATIO': '17.4', 'RM': '6.552'},
#  {'LSTAT': '11.65', 'MDEV': '510300.0', 'PTRATIO': '17.4', 'RM': '5.981'},
#  {'LSTAT': '5.25', 'MDEV': '665700.0', 'PTRATIO': '17.4', 'RM': '7.412'},
#  {'LSTAT': '2.47', 'MDEV': '875700.0', 'PTRATIO': '17.4', 'RM': '8.337'},
#  {'LSTAT': '3.95', 'MDEV': '1014300.0', 'PTRATIO': '17.4', 'RM': '8.247'},
#  {'LSTAT': '8.05', 'MDEV': '609000.0', 'PTRATIO': '17.4', 'RM': '6.726'},
#  {'LSTAT': '10.88', 'MDEV': '504000.0', 'PTRATIO': '17.4', 'RM': '6.086'},
#  {'LSTAT': '9.54', 'MDEV': '527100.0', 'PTRATIO': '17.4', 'RM': '6.631'},
#  {'LSTAT': '4.73', 'MDEV': '661500.0', 'PTRATIO': '17.4', 'RM': '7.358'},
#  {'LSTAT': '6.36', 'MDEV': '497700.0', 'PTRATIO': '16.6', 'RM': '6.481'},
#  {'LSTAT': '7.37', 'MDEV': '489300.0', 'PTRATIO': '16.6', 'RM': '6.606'},
#  {'LSTAT': '11.38', 'MDEV': '462000.0', 'PTRATIO': '16.6', 'RM': '6.897'},
#  {'LSTAT': '12.4', 'MDEV': '422100.0', 'PTRATIO': '16.6', 'RM': '6.095'},
#  {'LSTAT': '11.22', 'MDEV': '466200.0', 'PTRATIO': '16.6', 'RM': '6.358'},
#  {'LSTAT': '5.19', 'MDEV': '497700.0', 'PTRATIO': '16.6', 'RM': '6.393'},
#  {'LSTAT': '12.5', 'MDEV': '369600.0', 'PTRATIO': '19.1', 'RM': '5.593'},
#  {'LSTAT': '18.46', 'MDEV': '388500.0', 'PTRATIO': '19.1', 'RM': '5.605'},
#  {'LSTAT': '9.16', 'MDEV': '510300.0', 'PTRATIO': '19.1', 'RM': '6.108'},
#  {'LSTAT': '10.15', 'MDEV': '430500.0', 'PTRATIO': '19.1', 'RM': '6.226'},
#  {'LSTAT': '9.52', 'MDEV': '514500.0', 'PTRATIO': '19.1', 'RM': '6.433'},
#  {'LSTAT': '6.56', 'MDEV': '550200.0', 'PTRATIO': '19.1', 'RM': '6.718'},
#  {'LSTAT': '5.9', 'MDEV': '512400.0', 'PTRATIO': '19.1', 'RM': '6.487'},
#  {'LSTAT': '3.59', 'MDEV': '520800.0', 'PTRATIO': '19.1', 'RM': '6.438'},
#  {'LSTAT': '3.53', 'MDEV': '621600.0', 'PTRATIO': '19.1', 'RM': '6.957'},
#  {'LSTAT': '3.54', 'MDEV': '898800.0', 'PTRATIO': '19.1', 'RM': '8.259'},
#  {'LSTAT': '6.57', 'MDEV': '459900.0', 'PTRATIO': '16.4', 'RM': '6.108'},
#  {'LSTAT': '9.25', 'MDEV': '438900.0', 'PTRATIO': '16.4', 'RM': '5.876'},
#  {'LSTAT': '3.11', 'MDEV': '924000.0', 'PTRATIO': '15.9', 'RM': '7.454'},
#  {'LSTAT': '7.79', 'MDEV': '756000.0', 'PTRATIO': '13.0', 'RM': '7.333'},
#  {'LSTAT': '6.9', 'MDEV': '632100.0', 'PTRATIO': '13.0', 'RM': '6.842'},
#  {'LSTAT': '9.59', 'MDEV': '709800.0', 'PTRATIO': '13.0', 'RM': '7.203'},
#  {'LSTAT': '7.26', 'MDEV': '905100.0', 'PTRATIO': '13.0', 'RM': '7.52'},
#  {'LSTAT': '5.91', 'MDEV': '1024800.0', 'PTRATIO': '13.0', 'RM': '8.398'},
#  {'LSTAT': '11.25', 'MDEV': '651000.0', 'PTRATIO': '13.0', 'RM': '7.327'},
#  {'LSTAT': '8.1', 'MDEV': '766500.0', 'PTRATIO': '13.0', 'RM': '7.206'},
#  {'LSTAT': '10.45', 'MDEV': '478800.0', 'PTRATIO': '13.0', 'RM': '5.56'},
#  {'LSTAT': '14.79', 'MDEV': '644700.0', 'PTRATIO': '13.0', 'RM': '7.014'},
#  {'LSTAT': '3.16', 'MDEV': '913500.0', 'PTRATIO': '13.0', 'RM': '7.47'},
#  {'LSTAT': '13.65', 'MDEV': '434700.0', 'PTRATIO': '18.6', 'RM': '5.92'},
#  {'LSTAT': '13.0', 'MDEV': '443100.0', 'PTRATIO': '18.6', 'RM': '5.856'},
#  {'LSTAT': '6.59', 'MDEV': '529200.0', 'PTRATIO': '18.6', 'RM': '6.24'},
#  {'LSTAT': '7.73', 'MDEV': '512400.0', 'PTRATIO': '18.6', 'RM': '6.538'},
#  {'LSTAT': '6.58', 'MDEV': '739200.0', 'PTRATIO': '18.6', 'RM': '7.691'},
#  {'LSTAT': '3.53', 'MDEV': '680400.0', 'PTRATIO': '17.6', 'RM': '6.758'},
#  {'LSTAT': '2.98', 'MDEV': '672000.0', 'PTRATIO': '17.6', 'RM': '6.854'},
#  {'LSTAT': '6.05', 'MDEV': '697200.0', 'PTRATIO': '17.6', 'RM': '7.267'},
#  {'LSTAT': '4.16', 'MDEV': '695100.0', 'PTRATIO': '17.6', 'RM': '6.826'},
#  {'LSTAT': '7.19', 'MDEV': '611100.0', 'PTRATIO': '17.6', 'RM': '6.482'},
#  {'LSTAT': '4.85', 'MDEV': '737100.0', 'PTRATIO': '14.9', 'RM': '6.812'},
#  {'LSTAT': '3.76', 'MDEV': '953400.0', 'PTRATIO': '14.9', 'RM': '7.82'},
#  {'LSTAT': '4.59', 'MDEV': '743400.0', 'PTRATIO': '14.9', 'RM': '6.968'},
#  {'LSTAT': '3.01', 'MDEV': '966000.0', 'PTRATIO': '14.9', 'RM': '7.645'},
#  {'LSTAT': '7.85', 'MDEV': '676200.0', 'PTRATIO': '15.3', 'RM': '7.088'},
#  {'LSTAT': '8.23', 'MDEV': '462000.0', 'PTRATIO': '15.3', 'RM': '6.453'},
#  {'LSTAT': '12.93', 'MDEV': '422100.0', 'PTRATIO': '18.2', 'RM': '6.23'},
#  {'LSTAT': '7.14', 'MDEV': '487200.0', 'PTRATIO': '16.6', 'RM': '6.209'},
#  {'LSTAT': '7.6', 'MDEV': '468300.0', 'PTRATIO': '16.6', 'RM': '6.315'},
#  {'LSTAT': '9.51', 'MDEV': '520800.0', 'PTRATIO': '16.6', 'RM': '6.565'},
#  {'LSTAT': '3.33', 'MDEV': '598500.0', 'PTRATIO': '19.2', 'RM': '6.861'},
#  {'LSTAT': '3.56', 'MDEV': '783300.0', 'PTRATIO': '19.2', 'RM': '7.148'},
#  {'LSTAT': '4.7', 'MDEV': '585900.0', 'PTRATIO': '19.2', 'RM': '6.63'},
#  {'LSTAT': '8.58', 'MDEV': '501900.0', 'PTRATIO': '16.0', 'RM': '6.127'},
#  {'LSTAT': '10.4', 'MDEV': '455700.0', 'PTRATIO': '16.0', 'RM': '6.009'},
#  {'LSTAT': '6.27', 'MDEV': '600600.0', 'PTRATIO': '16.0', 'RM': '6.678'},
#  {'LSTAT': '7.39', 'MDEV': '569100.0', 'PTRATIO': '16.0', 'RM': '6.549'},
#  {'LSTAT': '15.84', 'MDEV': '426300.0', 'PTRATIO': '16.0', 'RM': '5.79'},
#  {'LSTAT': '4.97', 'MDEV': '472500.0', 'PTRATIO': '14.8', 'RM': '6.345'},
#  {'LSTAT': '4.74', 'MDEV': '609000.0', 'PTRATIO': '14.8', 'RM': '7.041'},
#  {'LSTAT': '6.07', 'MDEV': '520800.0', 'PTRATIO': '14.8', 'RM': '6.871'},
#  {'LSTAT': '9.5', 'MDEV': '462000.0', 'PTRATIO': '16.1', 'RM': '6.59'},
#  {'LSTAT': '8.67', 'MDEV': '554400.0', 'PTRATIO': '16.1', 'RM': '6.495'},
#  {'LSTAT': '4.86', 'MDEV': '695100.0', 'PTRATIO': '16.1', 'RM': '6.982'},
#  {'LSTAT': '6.93', 'MDEV': '758100.0', 'PTRATIO': '18.4', 'RM': '7.236'},
#  {'LSTAT': '8.93', 'MDEV': '596400.0', 'PTRATIO': '18.4', 'RM': '6.616'},
#  {'LSTAT': '6.47', 'MDEV': '701400.0', 'PTRATIO': '18.4', 'RM': '7.42'},
#  {'LSTAT': '7.53', 'MDEV': '592200.0', 'PTRATIO': '18.4', 'RM': '6.849'},
#  {'LSTAT': '4.54', 'MDEV': '478800.0', 'PTRATIO': '18.4', 'RM': '6.635'},
#  {'LSTAT': '9.97', 'MDEV': '426300.0', 'PTRATIO': '18.4', 'RM': '5.972'},
#  {'LSTAT': '12.64', 'MDEV': '338100.0', 'PTRATIO': '18.4', 'RM': '4.973'},
#  {'LSTAT': '5.98', 'MDEV': '464100.0', 'PTRATIO': '18.4', 'RM': '6.122'},
#  {'LSTAT': '11.72', 'MDEV': '407400.0', 'PTRATIO': '18.4', 'RM': '6.023'},
#  {'LSTAT': '7.9', 'MDEV': '453600.0', 'PTRATIO': '18.4', 'RM': '6.266'},
#  {'LSTAT': '9.28', 'MDEV': '499800.0', 'PTRATIO': '18.4', 'RM': '6.567'},
#  {'LSTAT': '11.5', 'MDEV': '340200.0', 'PTRATIO': '18.4', 'RM': '5.705'},
#  {'LSTAT': '18.33', 'MDEV': '373800.0', 'PTRATIO': '18.4', 'RM': '5.914'},
#  {'LSTAT': '15.94', 'MDEV': '415800.0', 'PTRATIO': '18.4', 'RM': '5.782'},
#  {'LSTAT': '10.36', 'MDEV': '485100.0', 'PTRATIO': '18.4', 'RM': '6.382'},
#  {'LSTAT': '12.73', 'MDEV': '441000.0', 'PTRATIO': '18.4', 'RM': '6.113'},
#  {'LSTAT': '7.2', 'MDEV': '499800.0', 'PTRATIO': '19.6', 'RM': '6.426'},
#  {'LSTAT': '6.87', 'MDEV': '485100.0', 'PTRATIO': '19.6', 'RM': '6.376'},
#  {'LSTAT': '7.7', 'MDEV': '428400.0', 'PTRATIO': '19.6', 'RM': '6.041'},
#  {'LSTAT': '11.74', 'MDEV': '388500.0', 'PTRATIO': '19.6', 'RM': '5.708'},
#  {'LSTAT': '6.12', 'MDEV': '525000.0', 'PTRATIO': '19.6', 'RM': '6.415'},
#  {'LSTAT': '5.08', 'MDEV': '516600.0', 'PTRATIO': '19.6', 'RM': '6.431'},
#  {'LSTAT': '6.15', 'MDEV': '483000.0', 'PTRATIO': '19.6', 'RM': '6.312'},
#  {'LSTAT': '12.79', 'MDEV': '466200.0', 'PTRATIO': '19.6', 'RM': '6.083'},
#  {'LSTAT': '9.97', 'MDEV': '405300.0', 'PTRATIO': '16.9', 'RM': '5.868'},
#  {'LSTAT': '7.34', 'MDEV': '474600.0', 'PTRATIO': '16.9', 'RM': '6.333'},
#  {'LSTAT': '9.09', 'MDEV': '415800.0', 'PTRATIO': '16.9', 'RM': '6.144'},
#  {'LSTAT': '12.43', 'MDEV': '359100.0', 'PTRATIO': '16.9', 'RM': '5.706'},
#  {'LSTAT': '7.83', 'MDEV': '407400.0', 'PTRATIO': '16.9', 'RM': '6.031'},
#  {'LSTAT': '5.68', 'MDEV': '466200.0', 'PTRATIO': '20.2', 'RM': '6.316'},
#  {'LSTAT': '6.75', 'MDEV': '434700.0', 'PTRATIO': '20.2', 'RM': '6.31'},
#  {'LSTAT': '8.01', 'MDEV': '443100.0', 'PTRATIO': '20.2', 'RM': '6.037'},
#  {'LSTAT': '9.8', 'MDEV': '409500.0', 'PTRATIO': '20.2', 'RM': '5.869'},
#  {'LSTAT': '10.56', 'MDEV': '388500.0', 'PTRATIO': '20.2', 'RM': '5.895'},
#  {'LSTAT': '8.51', 'MDEV': '432600.0', 'PTRATIO': '20.2', 'RM': '6.059'},
#  {'LSTAT': '9.74', 'MDEV': '399000.0', 'PTRATIO': '20.2', 'RM': '5.985'},
#  {'LSTAT': '9.29', 'MDEV': '392700.0', 'PTRATIO': '20.2', 'RM': '5.968'},
#  {'LSTAT': '5.49', 'MDEV': '686700.0', 'PTRATIO': '15.5', 'RM': '7.241'},
#  {'LSTAT': '8.65', 'MDEV': '346500.0', 'PTRATIO': '15.9', 'RM': '6.54'},
#  {'LSTAT': '7.18', 'MDEV': '501900.0', 'PTRATIO': '17.6', 'RM': '6.696'},
#  {'LSTAT': '4.61', 'MDEV': '655200.0', 'PTRATIO': '17.6', 'RM': '6.874'},
#  {'LSTAT': '10.53', 'MDEV': '367500.0', 'PTRATIO': '18.8', 'RM': '6.014'},
#  {'LSTAT': '12.67', 'MDEV': '361200.0', 'PTRATIO': '18.8', 'RM': '5.898'},
#  {'LSTAT': '6.36', 'MDEV': '485100.0', 'PTRATIO': '17.9', 'RM': '6.516'},
#  {'LSTAT': '5.99', 'MDEV': '514500.0', 'PTRATIO': '17.0', 'RM': '6.635'},
#  {'LSTAT': '5.89', 'MDEV': '558600.0', 'PTRATIO': '19.7', 'RM': '6.939'},
#  {'LSTAT': '5.98', 'MDEV': '480900.0', 'PTRATIO': '19.7', 'RM': '6.49'},
#  {'LSTAT': '5.49', 'MDEV': '506100.0', 'PTRATIO': '18.3', 'RM': '6.579'},
#  {'LSTAT': '7.79', 'MDEV': '390600.0', 'PTRATIO': '18.3', 'RM': '5.884'},
#  {'LSTAT': '4.5', 'MDEV': '632100.0', 'PTRATIO': '17.0', 'RM': '6.728'},
#  {'LSTAT': '8.05', 'MDEV': '382200.0', 'PTRATIO': '22.0', 'RM': '5.663'},
#  {'LSTAT': '5.57', 'MDEV': '432600.0', 'PTRATIO': '22.0', 'RM': '5.936'},
#  {'LSTAT': '17.6', 'MDEV': '373800.0', 'PTRATIO': '20.2', 'RM': '6.212'},
#  {'LSTAT': '13.27', 'MDEV': '455700.0', 'PTRATIO': '20.2', 'RM': '6.395'},
#  {'LSTAT': '11.48', 'MDEV': '476700.0', 'PTRATIO': '20.2', 'RM': '6.127'},
#  {'LSTAT': '12.67', 'MDEV': '474600.0', 'PTRATIO': '20.2', 'RM': '6.112'},
#  {'LSTAT': '7.79', 'MDEV': '525000.0', 'PTRATIO': '20.2', 'RM': '6.398'},
#  {'LSTAT': '14.19', 'MDEV': '417900.0', 'PTRATIO': '20.2', 'RM': '6.251'},
#  {'LSTAT': '10.19', 'MDEV': '436800.0', 'PTRATIO': '20.2', 'RM': '5.362'},
#  {'LSTAT': '14.64', 'MDEV': '352800.0', 'PTRATIO': '20.2', 'RM': '5.803'},
#  {'LSTAT': '7.12', 'MDEV': '577500.0', 'PTRATIO': '20.2', 'RM': '3.561'},
#  {'LSTAT': '14.0', 'MDEV': '459900.0', 'PTRATIO': '20.2', 'RM': '4.963'},
#  {'LSTAT': '13.33', 'MDEV': '485100.0', 'PTRATIO': '20.2', 'RM': '3.863'},
#  {'LSTAT': '34.77', 'MDEV': '289800.0', 'PTRATIO': '20.2', 'RM': '4.906'},
#  {'LSTAT': '37.97', 'MDEV': '289800.0', 'PTRATIO': '20.2', 'RM': '4.138'},
#  {'LSTAT': '13.44', 'MDEV': '315000.0', 'PTRATIO': '20.2', 'RM': '7.313'},
#  {'LSTAT': '23.24', 'MDEV': '291900.0', 'PTRATIO': '20.2', 'RM': '6.649'},
#  {'LSTAT': '21.24', 'MDEV': '279300.0', 'PTRATIO': '20.2', 'RM': '6.794'},
#  {'LSTAT': '23.69', 'MDEV': '275100.0', 'PTRATIO': '20.2', 'RM': '6.38'},
#  {'LSTAT': '21.78', 'MDEV': '214200.0', 'PTRATIO': '20.2', 'RM': '6.223'},
#  {'LSTAT': '17.21', 'MDEV': '218400.0', 'PTRATIO': '20.2', 'RM': '6.968'},
#  {'LSTAT': '21.08', 'MDEV': '228900.0', 'PTRATIO': '20.2', 'RM': '6.545'},
#  {'LSTAT': '23.6', 'MDEV': '237300.0', 'PTRATIO': '20.2', 'RM': '5.536'},
#  {'LSTAT': '24.56', 'MDEV': '258300.0', 'PTRATIO': '20.2', 'RM': '5.52'},
#  {'LSTAT': '30.63', 'MDEV': '184800.0', 'PTRATIO': '20.2', 'RM': '4.368'},
#  {'LSTAT': '30.81', 'MDEV': '151200.0', 'PTRATIO': '20.2', 'RM': '5.277'},
#  {'LSTAT': '28.28', 'MDEV': '220500.0', 'PTRATIO': '20.2', 'RM': '4.652'},
#  {'LSTAT': '31.99', 'MDEV': '155400.0', 'PTRATIO': '20.2', 'RM': '5.0'},
#  {'LSTAT': '30.62', 'MDEV': '214200.0', 'PTRATIO': '20.2', 'RM': '4.88'},
#  {'LSTAT': '20.85', 'MDEV': '241500.0', 'PTRATIO': '20.2', 'RM': '5.39'},
#  {'LSTAT': '17.11', 'MDEV': '317100.0', 'PTRATIO': '20.2', 'RM': '5.713'},
#  {'LSTAT': '18.76', 'MDEV': '487200.0', 'PTRATIO': '20.2', 'RM': '6.051'},
#  {'LSTAT': '25.68', 'MDEV': '203700.0', 'PTRATIO': '20.2', 'RM': '5.036'},
#  {'LSTAT': '15.17', 'MDEV': '289800.0', 'PTRATIO': '20.2', 'RM': '6.193'},
#  {'LSTAT': '16.35', 'MDEV': '266700.0', 'PTRATIO': '20.2', 'RM': '5.887'},
#  {'LSTAT': '17.12', 'MDEV': '275100.0', 'PTRATIO': '20.2', 'RM': '6.471'},
#  {'LSTAT': '19.37', 'MDEV': '262500.0', 'PTRATIO': '20.2', 'RM': '6.405'},
#  {'LSTAT': '19.92', 'MDEV': '178500.0', 'PTRATIO': '20.2', 'RM': '5.747'},
#  {'LSTAT': '30.59', 'MDEV': '105000.0', 'PTRATIO': '20.2', 'RM': '5.453'},
#  {'LSTAT': '29.97', 'MDEV': '132300.0', 'PTRATIO': '20.2', 'RM': '5.852'},
#  {'LSTAT': '26.77', 'MDEV': '117600.0', 'PTRATIO': '20.2', 'RM': '5.987'},
#  {'LSTAT': '20.32', 'MDEV': '151200.0', 'PTRATIO': '20.2', 'RM': '6.343'},
#  {'LSTAT': '20.31', 'MDEV': '254100.0', 'PTRATIO': '20.2', 'RM': '6.404'},
#  {'LSTAT': '19.77', 'MDEV': '174300.0', 'PTRATIO': '20.2', 'RM': '5.349'},
#  {'LSTAT': '27.38', 'MDEV': '178500.0', 'PTRATIO': '20.2', 'RM': '5.531'},
#  {'LSTAT': '22.98', 'MDEV': '105000.0', 'PTRATIO': '20.2', 'RM': '5.683'},
#  {'LSTAT': '23.34', 'MDEV': '249900.0', 'PTRATIO': '20.2', 'RM': '4.138'},
#  {'LSTAT': '12.13', 'MDEV': '585900.0', 'PTRATIO': '20.2', 'RM': '5.608'},
#  {'LSTAT': '26.4', 'MDEV': '361200.0', 'PTRATIO': '20.2', 'RM': '5.617'},
#  {'LSTAT': '19.78', 'MDEV': '577500.0', 'PTRATIO': '20.2', 'RM': '6.852'},
#  {'LSTAT': '10.11', 'MDEV': '315000.0', 'PTRATIO': '20.2', 'RM': '5.757'},
#  {'LSTAT': '21.22', 'MDEV': '361200.0', 'PTRATIO': '20.2', 'RM': '6.657'},
#  {'LSTAT': '34.37', 'MDEV': '375900.0', 'PTRATIO': '20.2', 'RM': '4.628'},
#  {'LSTAT': '20.08', 'MDEV': '342300.0', 'PTRATIO': '20.2', 'RM': '5.155'},
#  {'LSTAT': '36.98', 'MDEV': '147000.0', 'PTRATIO': '20.2', 'RM': '4.519'},
#  {'LSTAT': '29.05', 'MDEV': '151200.0', 'PTRATIO': '20.2', 'RM': '6.434'},
#  {'LSTAT': '25.79', 'MDEV': '157500.0', 'PTRATIO': '20.2', 'RM': '6.782'},
#  {'LSTAT': '26.64', 'MDEV': '218400.0', 'PTRATIO': '20.2', 'RM': '5.304'},
#  {'LSTAT': '20.62', 'MDEV': '184800.0', 'PTRATIO': '20.2', 'RM': '5.957'},
#  {'LSTAT': '22.74', 'MDEV': '176400.0', 'PTRATIO': '20.2', 'RM': '6.824'},
#  {'LSTAT': '15.02', 'MDEV': '350700.0', 'PTRATIO': '20.2', 'RM': '6.411'},
#  {'LSTAT': '15.7', 'MDEV': '298200.0', 'PTRATIO': '20.2', 'RM': '6.006'},
#  {'LSTAT': '14.1', 'MDEV': '436800.0', 'PTRATIO': '20.2', 'RM': '5.648'},
#  {'LSTAT': '23.29', 'MDEV': '281400.0', 'PTRATIO': '20.2', 'RM': '6.103'},
#  {'LSTAT': '17.16', 'MDEV': '245700.0', 'PTRATIO': '20.2', 'RM': '5.565'},
#  {'LSTAT': '24.39', 'MDEV': '174300.0', 'PTRATIO': '20.2', 'RM': '5.896'},
#  {'LSTAT': '15.69', 'MDEV': '214200.0', 'PTRATIO': '20.2', 'RM': '5.837'},
#  {'LSTAT': '14.52', 'MDEV': '228900.0', 'PTRATIO': '20.2', 'RM': '6.202'},
#  {'LSTAT': '21.52', 'MDEV': '231000.0', 'PTRATIO': '20.2', 'RM': '6.193'},
#  {'LSTAT': '24.08', 'MDEV': '199500.0', 'PTRATIO': '20.2', 'RM': '6.38'},
#  {'LSTAT': '17.64', 'MDEV': '304500.0', 'PTRATIO': '20.2', 'RM': '6.348'},
#  {'LSTAT': '19.69', 'MDEV': '296100.0', 'PTRATIO': '20.2', 'RM': '6.833'},
#  {'LSTAT': '12.03', 'MDEV': '338100.0', 'PTRATIO': '20.2', 'RM': '6.425'},
#  {'LSTAT': '16.22', 'MDEV': '300300.0', 'PTRATIO': '20.2', 'RM': '6.436'},
#  {'LSTAT': '15.17', 'MDEV': '245700.0', 'PTRATIO': '20.2', 'RM': '6.208'},
#  {'LSTAT': '23.27', 'MDEV': '281400.0', 'PTRATIO': '20.2', 'RM': '6.629'},
#  {'LSTAT': '18.05', 'MDEV': '201600.0', 'PTRATIO': '20.2', 'RM': '6.461'},
#  {'LSTAT': '26.45', 'MDEV': '182700.0', 'PTRATIO': '20.2', 'RM': '6.152'},
#  {'LSTAT': '34.02', 'MDEV': '176400.0', 'PTRATIO': '20.2', 'RM': '5.935'},
#  {'LSTAT': '22.88', 'MDEV': '268800.0', 'PTRATIO': '20.2', 'RM': '5.627'},
#  {'LSTAT': '22.11', 'MDEV': '220500.0', 'PTRATIO': '20.2', 'RM': '5.818'},
#  {'LSTAT': '19.52', 'MDEV': '359100.0', 'PTRATIO': '20.2', 'RM': '6.406'},
#  {'LSTAT': '16.59', 'MDEV': '386400.0', 'PTRATIO': '20.2', 'RM': '6.219'},
#  {'LSTAT': '18.85', 'MDEV': '323400.0', 'PTRATIO': '20.2', 'RM': '6.485'},
#  {'LSTAT': '23.79', 'MDEV': '226800.0', 'PTRATIO': '20.2', 'RM': '5.854'},
#  {'LSTAT': '23.98', 'MDEV': '247800.0', 'PTRATIO': '20.2', 'RM': '6.459'},
#  {'LSTAT': '17.79', 'MDEV': '312900.0', 'PTRATIO': '20.2', 'RM': '6.341'},
#  {'LSTAT': '16.44', 'MDEV': '264600.0', 'PTRATIO': '20.2', 'RM': '6.251'},
#  {'LSTAT': '18.13', 'MDEV': '296100.0', 'PTRATIO': '20.2', 'RM': '6.185'},
#  {'LSTAT': '19.31', 'MDEV': '273000.0', 'PTRATIO': '20.2', 'RM': '6.417'},
#  {'LSTAT': '17.44', 'MDEV': '281400.0', 'PTRATIO': '20.2', 'RM': '6.749'},
#  {'LSTAT': '17.73', 'MDEV': '319200.0', 'PTRATIO': '20.2', 'RM': '6.655'},
#  {'LSTAT': '17.27', 'MDEV': '338100.0', 'PTRATIO': '20.2', 'RM': '6.297'},
#  {'LSTAT': '16.74', 'MDEV': '373800.0', 'PTRATIO': '20.2', 'RM': '7.393'},
#  {'LSTAT': '18.71', 'MDEV': '312900.0', 'PTRATIO': '20.2', 'RM': '6.728'},
#  {'LSTAT': '18.13', 'MDEV': '296100.0', 'PTRATIO': '20.2', 'RM': '6.525'},
#  {'LSTAT': '19.01', 'MDEV': '266700.0', 'PTRATIO': '20.2', 'RM': '5.976'},
#  {'LSTAT': '16.94', 'MDEV': '283500.0', 'PTRATIO': '20.2', 'RM': '5.936'},
#  {'LSTAT': '16.23', 'MDEV': '312900.0', 'PTRATIO': '20.2', 'RM': '6.301'},
#  {'LSTAT': '14.7', 'MDEV': '420000.0', 'PTRATIO': '20.2', 'RM': '6.081'},
#  {'LSTAT': '16.42', 'MDEV': '344400.0', 'PTRATIO': '20.2', 'RM': '6.701'},
#  {'LSTAT': '14.65', 'MDEV': '371700.0', 'PTRATIO': '20.2', 'RM': '6.376'},
#  {'LSTAT': '13.99', 'MDEV': '409500.0', 'PTRATIO': '20.2', 'RM': '6.317'},
#  {'LSTAT': '10.29', 'MDEV': '424200.0', 'PTRATIO': '20.2', 'RM': '6.513'},
#  {'LSTAT': '13.22', 'MDEV': '449400.0', 'PTRATIO': '20.2', 'RM': '6.209'},
#  {'LSTAT': '14.13', 'MDEV': '417900.0', 'PTRATIO': '20.2', 'RM': '5.759'},
#  {'LSTAT': '17.15', 'MDEV': '399000.0', 'PTRATIO': '20.2', 'RM': '5.952'},
#  {'LSTAT': '21.32', 'MDEV': '401100.0', 'PTRATIO': '20.2', 'RM': '6.003'},
#  {'LSTAT': '18.13', 'MDEV': '401100.0', 'PTRATIO': '20.2', 'RM': '5.926'},
#  {'LSTAT': '14.76', 'MDEV': '422100.0', 'PTRATIO': '20.2', 'RM': '5.713'},
#  {'LSTAT': '16.29', 'MDEV': '417900.0', 'PTRATIO': '20.2', 'RM': '6.167'},
#  {'LSTAT': '12.87', 'MDEV': '411600.0', 'PTRATIO': '20.2', 'RM': '6.229'},
#  {'LSTAT': '14.36', 'MDEV': '487200.0', 'PTRATIO': '20.2', 'RM': '6.437'},
#  {'LSTAT': '11.66', 'MDEV': '625800.0', 'PTRATIO': '20.2', 'RM': '6.98'},
#  {'LSTAT': '18.14', 'MDEV': '289800.0', 'PTRATIO': '20.2', 'RM': '5.427'},
#  {'LSTAT': '24.1', 'MDEV': '279300.0', 'PTRATIO': '20.2', 'RM': '6.162'},
#  {'LSTAT': '18.68', 'MDEV': '350700.0', 'PTRATIO': '20.2', 'RM': '6.484'},
#  {'LSTAT': '24.91', 'MDEV': '252000.0', 'PTRATIO': '20.2', 'RM': '5.304'},
#  {'LSTAT': '18.03', 'MDEV': '306600.0', 'PTRATIO': '20.2', 'RM': '6.185'},
#  {'LSTAT': '13.11', 'MDEV': '449400.0', 'PTRATIO': '20.2', 'RM': '6.229'},
#  {'LSTAT': '10.74', 'MDEV': '483000.0', 'PTRATIO': '20.2', 'RM': '6.242'},
#  {'LSTAT': '7.74', 'MDEV': '497700.0', 'PTRATIO': '20.2', 'RM': '6.75'},
#  {'LSTAT': '7.01', 'MDEV': '525000.0', 'PTRATIO': '20.2', 'RM': '7.061'},
#  {'LSTAT': '10.42', 'MDEV': '457800.0', 'PTRATIO': '20.2', 'RM': '5.762'},
#  {'LSTAT': '13.34', 'MDEV': '432600.0', 'PTRATIO': '20.2', 'RM': '5.871'},
#  {'LSTAT': '10.58', 'MDEV': '445200.0', 'PTRATIO': '20.2', 'RM': '6.312'},
#  {'LSTAT': '14.98', 'MDEV': '401100.0', 'PTRATIO': '20.2', 'RM': '6.114'},
#  {'LSTAT': '11.45', 'MDEV': '432600.0', 'PTRATIO': '20.2', 'RM': '5.905'},
#  {'LSTAT': '18.06', 'MDEV': '319200.0', 'PTRATIO': '20.1', 'RM': '5.454'},
#  {'LSTAT': '23.97', 'MDEV': '147000.0', 'PTRATIO': '20.1', 'RM': '5.414'},
#  {'LSTAT': '29.68', 'MDEV': '170100.0', 'PTRATIO': '20.1', 'RM': '5.093'},
#  {'LSTAT': '18.07', 'MDEV': '285600.0', 'PTRATIO': '20.1', 'RM': '5.983'},
#  {'LSTAT': '13.35', 'MDEV': '422100.0', 'PTRATIO': '20.1', 'RM': '5.983'},
#  {'LSTAT': '12.01', 'MDEV': '457800.0', 'PTRATIO': '19.2', 'RM': '5.707'},
#  {'LSTAT': '13.59', 'MDEV': '514500.0', 'PTRATIO': '19.2', 'RM': '5.926'},
#  {'LSTAT': '17.6', 'MDEV': '485100.0', 'PTRATIO': '19.2', 'RM': '5.67'},
#  {'LSTAT': '21.14', 'MDEV': '413700.0', 'PTRATIO': '19.2', 'RM': '5.39'},
#  {'LSTAT': '14.1', 'MDEV': '384300.0', 'PTRATIO': '19.2', 'RM': '5.794'},
#  {'LSTAT': '12.92', 'MDEV': '445200.0', 'PTRATIO': '19.2', 'RM': '6.019'},
#  {'LSTAT': '15.1', 'MDEV': '367500.0', 'PTRATIO': '19.2', 'RM': '5.569'},
#  {'LSTAT': '14.33', 'MDEV': '352800.0', 'PTRATIO': '19.2', 'RM': '6.027'},
#  {'LSTAT': '9.67', 'MDEV': '470400.0', 'PTRATIO': '21.0', 'RM': '6.593'},
#  {'LSTAT': '9.08', 'MDEV': '432600.0', 'PTRATIO': '21.0', 'RM': '6.12'},
#  {'LSTAT': '5.64', 'MDEV': '501900.0', 'PTRATIO': '21.0', 'RM': '6.976'},
#  {'LSTAT': '6.48', 'MDEV': '462000.0', 'PTRATIO': '21.0', 'RM': '6.794'},
#  {'LSTAT': '7.88', 'MDEV': '249900.0', 'PTRATIO': '21.0', 'RM': '6.03'}]

# %%
deserialized = json.loads(serialized)
deserialized[0]
# Out:
# {'LSTAT': '4.98', 'MDEV': '504000.0', 'PTRATIO': '15.3', 'RM': '6.575'}

# %% [markdown]
# #  Sources of Data
#
# Where do data come from?
#
# * Filesystem
# * Network server
#
# Also (in follow-on lectures):
# * Relational Databases (e.g. Oracle, MySQL, PostgreSQL)
# * Non-relational Database (e.g. NoSQL)

# %% [markdown]
# # The Filesystem
#
# * It's a place (system?) to keep files
# * It normally forms a tree with the computer at the top
# * It's got _directories_ and _files_ in it.

# %%
# Filesystem

#  We can read the whole thing...
f = open('./README.md', 'r')
contents = f.read()
f.close()
print('%d characters' % len(contents))

#  We can read a line at a time...
f = open('./README.md', 'r')
lines = [line for line in f.readlines()]
f.close()
print('%d lines' % len(lines))

#  We can read a line at a time...
with open('./README.md', 'r') as f:
    line_counts = [len(line) for line in f.readlines()]
line_counts
# Out:
# 315 characters
# 9 lines
# [1, 76, 71, 1, 107, 1, 56, 1, 1]

# %%
print(lines)
# Out:
# ['\n', 'The following command will start the datascience notebook docker image and \n', 'mount `repos/data601` from your home directory into the `work` folder.\n', '\n', '    docker run -it --rm -v $HOME/repos/data601:/home/jovyan/work -p 8888:8888 jupyter/datascience-notebook\n', '\n', 'From here you can run R, Julia, and python 3 notebooks.\n', '\n', '\n']

# %% [markdown]
# # Network servers
#
# * Many moons ago there were arguments about how computers should connect to each other over the internet
# * The agreed-upon rules that people designed are called _protocols_
# * Long ago TCP/IP won _mindshare_ due to simplicity (comparatively), effectiveness, and openness

# %% [markdown]
# * Back then there was no "web", just an internet
# * In the years since then, HTTP (which runs on top of TCP/IP) has also taken over an enormous amount of marketshare
#
# ## You can get remarkably far just by knowing how to fetch data over the web

# %%
import requests
response = requests.get('https://raw.githubusercontent.com/ggallo/boston-housing/master/housing.csv')
response


response2 = requests.get('https://en.wikipedia.org')
response2.ok
response2.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":807996266,"wgRevisionId":807996266,"wgArticleId":15580374,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgRequestId":"WsVV1QpAIC4AAGmUEq8AAACA","wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["sysop"],"wgRestrictionMove":["sysop"],"wgIsMainPage":true,"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\\"mode\\":0,\\"hideprefix\\":20,\\"showcount\\":true,\\"namespaces\\":false}","wgWikibaseItemId":"Q5296","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.tokens@1dqfd7l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});mw.loader.load(["site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget. ...

# %% [markdown]
# HTTP responses include a "status code".  This is an integer that tells you if it worked (e.g. `200 OK`) or failed (e.g. `404 Not Found`).
#
# In the above example, we were able to load the page.  Let's see what it contains...

# %%
response.text
# Out:
# 'RM,LSTAT,PTRATIO,MDEV\n6.575,4.98,15.3,504000.0\n6.421,9.14,17.8,453600.0\n7.185,4.03,17.8,728700.0\n6.998,2.94,18.7,701400.0\n7.147,5.33,18.7,760200.0\n6.43,5.21,18.7,602700.0\n6.012,12.43,15.2,480900.0\n6.172,19.15,15.2,569100.0\n5.631,29.93,15.2,346500.0\n6.004,17.1,15.2,396900.0\n6.377,20.45,15.2,315000.0\n6.009,13.27,15.2,396900.0\n5.889,15.71,15.2,455700.0\n5.949,8.26,21.0,428400.0\n6.096,10.26,21.0,382200.0\n5.834,8.47,21.0,417900.0\n5.935,6.58,21.0,485100.0\n5.99,14.67,21.0,367500.0\n5.456,11.69,21.0,424200.0\n5.727,11.28,21.0,382200.0\n5.57,21.02,21.0,285600.0\n5.965,13.83,21.0,411600.0\n6.142,18.72,21.0,319200.0\n5.813,19.88,21.0,304500.0\n5.924,16.3,21.0,327600.0\n5.599,16.51,21.0,291900.0\n5.813,14.81,21.0,348600.0\n6.047,17.28,21.0,310800.0\n6.495,12.8,21.0,386400.0\n6.674,11.98,21.0,441000.0\n5.713,22.6,21.0,266700.0\n6.072,13.04,21.0,304500.0\n5.95,27.71,21.0,277200.0\n5.701,18.35,21.0,275100.0\n6.096,20.34,21.0,283500.0\n5.933,9.68,19.2,396900.0\n5.841,11.41,19.2,420000.0\n5.85,8.77,19.2,441000.0\n5.966,10.13,19.2,518700.0\n6.595,4.32,18.3,646800.0\n7.024,1.98,18.3,732900.0\n6.77,4.84,17.9,558600.0\n6.169,5.81,17.9,531300.0\n6.211,7.44,17.9,518700.0\n6.069,9.55,17.9,445200.0\n5.682,10.21,17.9,405300.0\n5.786,14.15,17.9,420000.0\n6.03,18.8,17.9,348600.0\n5.399,30.81,17.9,302400.0\n5.602,16.2,17.9,407400.0\n5.963,13.45,16.8,413700.0\n6.115,9.43,16.8,430500.0\n6.511,5.28,16.8,525000.0\n5.998,8.43,16.8,491400.0\n5.888,14.8,21.1,396900.0\n7.249,4.81,17.9,743400.0\n6.383,5.77,17.3,518700.0\n6.816,3.95,15.1,663600.0\n6.145,6.86,19.7,489300.0\n5.927,9.22,19.7,411600.0\n5.741,13.15,19.7,392700.0\n5.966,14.44,19.7,336000.0\n6.456,6.73,19.7,466200.0\n6.762,9.5,19.7,525000.0\n7.104,8.05,18.6,693000.0\n6.29,4.67,16.1,493500.0\n5.787,10.24,16.1,407400.0\n5.878,8.1,18.9,462000.0\n5.594,13.09,18.9,365400.0\n5.885,8.79,18.9,438900.0\n6.417,6.72,19.2,508200.0\n5.961,9.88,19.2,455700.0\n6.065,5.52,19.2,478800.0\n6.245,7.54,19.2,491400.0\n6.273,6.78,18.7,506100.0\n6.286,8.94,18.7,449400.0\n6.279,11.97,18.7,420000.0\n6.14,10.27,18.7,436800.0\n6.232,12.34,18.7,445200.0\n5.874,9.1,18.7,426300.0\n6.727,5.29,19.0,588000.0\n6.619,7.22,19.0,501900.0\n6.302,6.72,19.0,520800.0\n6.167,7.51,19.0,480900.0\n6.389,9.62,18.5,501900.0\n6.63,6.53,18.5,558600.0\n6.015,12.86,18.5,472500.0\n6.121,8.44,18.5,466200.0\n7.007,5.5,17.8,495600.0\n7.079,5.7,17.8,602700.0\n6.417,8.81,17.8,474600.0\n6.405,8.2,17.8,462000.0\n6.442,8.16,18.2,480900.0\n6.211,6.21,18.2,525000.0\n6.249,10.59,18.2,432600.0\n6.625,6.65,18.0,596400.0\n6.163,11.34,18.0,449400.0\n8.069,4.21,18.0,812700.0\n7.82,3.57,18.0,919800.0\n7.416,6.19,18.0,697200.0\n6.727,9.42,20.9,577500.0\n6.781,7.67,20.9,556500.0\n6.405,10.63,20.9,390600.0\n6.137,13.44,20.9,405300.0\n6.167,12.33,20.9,422100.0\n5.851,16.47,20.9,409500.0\n5.836,18.66,20.9,409500.0\n6.127,14.09,20.9,428400.0\n6.474,12.27,20.9,415800.0\n6.229,15.55,20.9,407400.0\n6.195,13.0,20.9,455700.0\n6.715,10.16,17.8,478800.0\n5.913,16.21,17.8,394800.0\n6.092,17.09,17.8,392700.0\n6.254,10.45,17.8,388500.0\n5.928,15.76,17.8,384300.0\n6.176,12.04,17.8,445200.0\n6.021,10.3,17.8,403200.0\n5.872,15.37,17.8,428400.0\n5.731,13.61,17.8,405300.0\n5.87,14.37,19.1,462000.0\n6.004,14.27,19.1,426300.0\n5.961,17.93,19.1,430500.0\n5.856,25.41,19.1,363300.0\n5.879,17.58,19.1,394800.0\n5.986,14.81,19.1,449400.0\n5.613,27.26,19.1,329700.0\n5.693,17.19,21.2,340200.0\n6.431,15.39,21.2,378000.0\n5.637,18.34,21.2,300300.0\n6.458,12.6,21.2,403200.0\n6.326,12.26,21.2,411600.0\n6.372,11.12,21.2,483000.0\n5.822,15.03,21.2,386400.0\n5.757,17.31,21.2,327600.0\n6.335,16.96,21.2,380100.0\n5.942,16.9,21.2,365400.0\n6.454,14.59,21.2,359100.0\n5.857,21.32,21.2,279300.0\n6.151,18.46,21.2,373800.0\n6.174,24.16,21.2,294000.0\n5.019,34.41,21.2,302400.0\n5.403,26.82,14.7,281400.0\n5.468,26.42,14.7,327600.0\n4.903,29.29,14.7,247800.0\n6.13,27.8,14.7,289800.0\n5.628,16.65,14.7,327600.0\n4.926,29.53,14.7,306600.0\n5.186,28.32,14.7,373800.0\n5.597,21.45,14.7,323400.0\n6.122,14.1,14. ...

# %% [markdown]
# # Before we leave data formats, let's take a quick peek where we're headed next...

# %%
import pandas as pd

housing_data = pd.DataFrame.from_csv('https://raw.githubusercontent.com/ggallo/boston-housing/master/housing.csv', index_col=None)
housing_data
# Out:
# /Users/jmk/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   This is separate from the ipykernel package so we can avoid doing imports until
#         RM  LSTAT  PTRATIO      MDEV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# 5    6.430   5.21     18.7  602700.0
# 6    6.012  12.43     15.2  480900.0
# 7    6.172  19.15     15.2  569100.0
# 8    5.631  29.93     15.2  346500.0
# 9    6.004  17.10     15.2  396900.0
# 10   6.377  20.45     15.2  315000.0
# 11   6.009  13.27     15.2  396900.0
# 12   5.889  15.71     15.2  455700.0
# 13   5.949   8.26     21.0  428400.0
# 14   6.096  10.26     21.0  382200.0
# 15   5.834   8.47     21.0  417900.0
# 16   5.935   6.58     21.0  485100.0
# 17   5.990  14.67     21.0  367500.0
# 18   5.456  11.69     21.0  424200.0
# 19   5.727  11.28     21.0  382200.0
# 20   5.570  21.02     21.0  285600.0
# 21   5.965  13.83     21.0  411600.0
# 22   6.142  18.72     21.0  319200.0
# 23   5.813  19.88     21.0  304500.0
# 24   5.924  16.30     21.0  327600.0
# 25   5.599  16.51     21.0  291900.0
# 26   5.813  14.81     21.0  348600.0
# 27   6.047  17.28     21.0  310800.0
# 28   6.495  12.80     21.0  386400.0
# 29   6.674  11.98     21.0  441000.0
# ..     ...    ...      ...       ...
# 459  6.484  18.68     20.2  350700.0
# 460  5.304  24.91     20.2  252000.0
# 461  6.185  18.03     20.2  306600.0
# 462  6.229  13.11     20.2  449400.0
# 463  6.242  10.74     20.2  483000.0
# 464  6.750   7.74     20.2  497700.0
# 465  7.061   7.01     20.2  525000.0
# 466  5.762  10.42     20.2  457800.0
# 467  5.871  13.34     20.2  432600.0
# 468  6.312  10.58     20.2  445200.0
# 469  6.114  14.98     20.2  401100.0
# 470  5.905  11.45     20.2  432600.0
# 471  5.454  18.06     20.1  319200.0
# 472  5.414  23.97     20.1  147000.0
# 473  5.093  29.68     20.1  170100.0
# 474  5.983  18.07     20.1  285600.0
# 475  5.983  13.35     20.1  422100.0
# 476  5.707  12.01     19.2  457800.0
# 477  5.926  13.59     19.2  514500.0
# 478  5.670  17.60     19.2  485100.0
# 479  5.390  21.14     19.2  413700.0
# 480  5.794  14.10     19.2  384300.0
# 481  6.019  12.92     19.2  445200.0
# 482  5.569  15.10     19.2  367500.0
# 483  6.027  14.33     19.2  352800.0
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %% [markdown]
# ## Looks handy, right?  Welcome to pandas.
#
# But first, let's look under the hood of pandas at NumPy - the heart of all of data science in python.
